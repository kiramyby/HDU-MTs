# %%
# This mounts your Google Drive to the Colab VM.
from google.colab import drive
drive.mount('/content/drive')

# TODO: Enter the foldername in your Drive where you have saved the unzipped
# assignment folder, e.g. 'cs231n/assignments/assignment1/'
FOLDERNAME = 'cs231n/assignments/assignment1/'
assert FOLDERNAME is not None, "[!] Enter the foldername."

# Now that we've mounted your Drive, this ensures that
# the Python interpreter of the Colab VM can load
# python files from within it.
import sys
sys.path.append('/content/drive/My Drive/{}'.format(FOLDERNAME))

# This downloads the CIFAR-10 dataset to your Drive
# if it doesn't already exist.
# %cd /content/drive/My\ Drive/$FOLDERNAME/cs231n/datasets/
# %cd /content/drive/My\ Drive/$FOLDERNAME
# !bash get_datasets.sh
# %cd /content/drive/My\ Drive/$FOLDERNAME

# %% [markdown]
# # Multi-Layer Fully Connected Network
# In this exercise, you will implement a fully connected network with an arbitrary number of hidden layers.

# %%
# from google.colab import drive
# drive.mount('/content/drive')

# %% [markdown]
# Read through the `FullyConnectedNet` class in the file `cs231n/classifiers/fc_net.py`.
#
# Implement the network initialization, forward pass, and backward pass. Throughout this assignment, you will be implementing layers in `cs231n/layers.py`. You can re-use your implementations for `affine_forward`, `affine_backward`, `relu_forward`, `relu_backward`, and `softmax_loss` from before. For right now, don't worry about implementing dropout or batch/layer normalization yet, as you will add those features later.

# %%
# Setup cell.
import time
import numpy as np
import matplotlib.pyplot as plt
from cs231n.classifiers.fc_net import *
from cs231n.data_utils import get_CIFAR10_data
from cs231n.gradient_check import eval_numerical_gradient, eval_numerical_gradient_array
from cs231n.solver import Solver

# %matplotlib inline
plt.rcParams["figure.figsize"] = (10.0, 8.0)  # Set default size of plots.
plt.rcParams["image.interpolation"] = "nearest"
plt.rcParams["image.cmap"] = "gray"

# %load_ext autoreload
# %autoreload 2

def rel_error(x, y):
    """Returns relative error."""
    return np.max(np.abs(x - y) / (np.maximum(1e-8, np.abs(x) + np.abs(y))))

# %%
# Load the (preprocessed) CIFAR-10 data.
data = get_CIFAR10_data()
for k, v in list(data.items()):
    print(f"{k}: {v.shape}")
# Out:
# X_train: (49000, 3, 32, 32)
# y_train: (49000,)
# X_val: (1000, 3, 32, 32)
# y_val: (1000,)
# X_test: (1000, 3, 32, 32)
# y_test: (1000,)

# %% [markdown]
# ## Initial Loss and Gradient Check
#
# As a sanity check, run the following to check the initial loss and to gradient check the network both with and without regularization. This is a good way to see if the initial losses seem reasonable.
#
# For gradient checking, you should expect to see errors around 1e-7 or less.

# %%
np.random.seed(231)
N, D, H1, H2, C = 2, 15, 20, 30, 10
X = np.random.randn(N, D)
y = np.random.randint(C, size=(N,))

for reg in [0, 3.14]:
    print("Running check with reg = ", reg)
    model = FullyConnectedNet(
        [H1, H2],
        input_dim=D,
        num_classes=C,
        reg=reg,
        weight_scale=5e-2,
        dtype=np.float64
    )

    loss, grads = model.loss(X, y)
    print("Initial loss: ", loss)

    # Most of the errors should be on the order of e-7 or smaller.
    # NOTE: It is fine however to see an error for W2 on the order of e-5
    # for the check when reg = 0.0
    for name in sorted(grads):
        f = lambda _: model.loss(X, y)[0]
        grad_num = eval_numerical_gradient(f, model.params[name], verbose=False, h=1e-5)
        print(f"{name} relative error: {rel_error(grad_num, grads[name])}")
# Out:
# Running check with reg =  0
# Initial loss:  2.300479089768492
# W1 relative error: 1.0252674374835853e-07
# W2 relative error: 2.2120479365657735e-05
# W3 relative error: 4.5623278853694277e-07
# b1 relative error: 4.660094280453673e-09
# b2 relative error: 2.085654276112763e-09
# b3 relative error: 1.689724888469736e-10
# Running check with reg =  3.14
# Initial loss:  7.052114776533016
# W1 relative error: 6.862885011277021e-09
# W2 relative error: 9.627270211033322e-08
# W3 relative error: 2.6171457581890515e-08
# b1 relative error: 1.4752427836900184e-08
# b2 relative error: 1.7223750761525226e-09
# b3 relative error: 2.378772438198909e-10
# W2 relative error: 9.627270211033322e-08
# W3 relative error: 2.6171457581890515e-08
# b1 relative error: 1.4752427836900184e-08
# b2 relative error: 1.7223750761525226e-09
# b3 relative error: 2.378772438198909e-10

# %% [markdown]
# As another sanity check, make sure your network can overfit on a small dataset of 50 images. First, we will try a three-layer network with 100 units in each hidden layer. In the following cell, tweak the **learning rate** and **weight initialization scale** to overfit and achieve 100% training accuracy within 20 epochs.

# %%
# TODO: Use a three-layer Net to overfit 50 training examples by
# tweaking just the learning rate and initialization scale.

num_train = 50
small_data = {
  "X_train": data["X_train"][:num_train],
  "y_train": data["y_train"][:num_train],
  "X_val": data["X_val"],
  "y_val": data["y_val"],
}

weight_scale_candidates = [3e-2, 5e-2, 7e-2]
learning_rate_candidates = [5e-2, 7.5e-2, 1e-1, 1.5e-1]

overfit_target = 0.999
best_solver_3layer = None
best_stats_3layer = None
best_train_acc = -1

for weight_scale in weight_scale_candidates:
    for learning_rate in learning_rate_candidates:
        model = FullyConnectedNet(
            [100, 100],
            weight_scale=weight_scale,
            dtype=np.float64
        )
        solver = Solver(
            model,
            small_data,
            print_every=10,
            num_epochs=20,
            batch_size=25,
            update_rule="sgd", 
            optim_config={"learning_rate": learning_rate},
        )
        solver.train()
        train_acc = solver.train_acc_history[-1]
        val_acc = solver.val_acc_history[-1]
        print(f"weight_scale={weight_scale:.2e}, lr={learning_rate:.2e}, train_acc={train_acc:.4f}, val_acc={val_acc:.4f}")
        if train_acc > best_train_acc:
            best_train_acc = train_acc
            best_solver_3layer = solver
            best_stats_3layer = {
                "weight_scale": weight_scale,
                "learning_rate": learning_rate,
            }
        if train_acc >= overfit_target:
            break
    if best_train_acc >= overfit_target:
        break

solver = best_solver_3layer
print("最佳三层网络配置:", best_stats_3layer)
plt.plot(solver.loss_history)
plt.title("Training loss history (best 3-layer net)")
plt.xlabel("Iteration")
plt.ylabel("Training loss")
plt.grid(linestyle='--', linewidth=0.5)
plt.show()
# Out:
# (Iteration 1 / 40) loss: 9.817983
# (Epoch 0 / 20) train acc: 0.100000; val_acc: 0.107000
# (Epoch 1 / 20) train acc: 0.120000; val_acc: 0.105000
# (Epoch 2 / 20) train acc: 0.120000; val_acc: 0.119000
# (Epoch 3 / 20) train acc: 0.100000; val_acc: 0.075000
# /Users/kiracoon/college/HDU-MTs/DeepLearning/assignment1/cs231n/layers.py:912: RuntimeWarning: divide by zero encountered in log
#   loss = -np.sum(np.log(probs[np.arange(N), y])) / N
# (Epoch 4 / 20) train acc: 0.100000; val_acc: 0.102000
# (Epoch 5 / 20) train acc: 0.100000; val_acc: 0.102000
# (Iteration 11 / 40) loss: 2.297294
# (Epoch 6 / 20) train acc: 0.120000; val_acc: 0.104000
# (Epoch 7 / 20) train acc: 0.120000; val_acc: 0.104000
# (Epoch 8 / 20) train acc: 0.120000; val_acc: 0.104000
# (Epoch 6 / 20) train acc: 0.120000; val_acc: 0.104000
# (Epoch 7 / 20) train acc: 0.120000; val_acc: 0.104000
# (Epoch 8 / 20) train acc: 0.120000; val_acc: 0.104000
# (Epoch 9 / 20) train acc: 0.120000; val_acc: 0.104000
# (Epoch 10 / 20) train acc: 0.120000; val_acc: 0.104000
# (Iteration 21 / 40) loss: 2.298426
# (Epoch 11 / 20) train acc: 0.120000; val_acc: 0.104000
# (Epoch 12 / 20) train acc: 0.120000; val_acc: 0.104000
# (Epoch 9 / 20) train acc: 0.120000; val_acc: 0.104000
# (Epoch 10 / 20) train acc: 0.120000; val_acc: 0.104000
# (Iteration 21 / 40) loss: 2.298426
# (Epoch 11 / 20) train acc: 0.120000; val_acc: 0.104000
# (Epoch 12 / 20) train acc: 0.120000; val_acc: 0.104000
# (Epoch 13 / 20) train acc: 0.120000; val_acc: 0.104000
# (Epoch 14 / 20) train acc: 0.120000; val_acc: 0.104000
# (Epoch 13 / 20) train acc: 0.120000; val_acc: 0.104000
# (Epoch 14 / 20) train acc: 0.120000; val_acc: 0.104000
# (Epoch 15 / 20) train acc: 0.120000; val_acc: 0.104000
# (Iteration 31 / 40) loss: 2.285878
# (Epoch 16 / 20) train acc: 0.160000; val_acc: 0.112000
# (Epoch 17 / 20) train acc: 0.160000; val_acc: 0.112000
# (Epoch 15 / 20) train acc: 0.120000; val_acc: 0.104000
# (Iteration 31 / 40) loss: 2.285878
# (Epoch 16 / 20) train acc: 0.160000; val_acc: 0.112000
# (Epoch 17 / 20) train acc: 0.160000; val_acc: 0.112000
# (Epoch 18 / 20) train acc: 0.160000; val_acc: 0.112000
# (Epoch 19 / 20) train acc: 0.160000; val_acc: 0.112000
# (Epoch 20 / 20) train acc: 0.160000; val_acc: 0.112000
# weight_scale=3.00e-02, lr=5.00e-02, train_acc=0.1600, val_acc=0.1120
# (Iteration 1 / 40) loss: 7.840284
# (Epoch 18 / 20) train acc: 0.160000; val_acc: 0.112000
# (Epoch 19 / 20) train acc: 0.160000; val_acc: 0.112000
# (Epoch 20 / 20) train acc: 0.160000; val_acc: 0.112000
# weight_scale=3.00e-02, lr=5.00e-02, train_acc=0.1600, val_acc=0.1120
# (Iteration 1 / 40) loss: 7.840284
# (Epoch 0 / 20) train acc: 0.180000; val_acc: 0.115000
# (Epoch 1 / 20) train acc: 0.160000; val_acc: 0.079000
# (Epoch 0 / 20) train acc: 0.180000; val_acc: 0.115000
# (Epoch 1 / 20) train acc: 0.160000; val_acc: 0.079000
# (Epoch 2 / 20) train acc: 0.160000; val_acc: 0.121000
# (Epoch 3 / 20) train acc: 0.060000; val_acc: 0.125000
# (Epoch 4 / 20) train acc: 0.080000; val_acc: 0.084000
# (Epoch 5 / 20) train acc: 0.220000; val_acc: 0.128000
# (Iteration 11 / 40) loss: inf
# (Epoch 2 / 20) train acc: 0.160000; val_acc: 0.121000
# (Epoch 3 / 20) train acc: 0.060000; val_acc: 0.125000
# (Epoch 4 / 20) train acc: 0.080000; val_acc: 0.084000
# (Epoch 5 / 20) train acc: 0.220000; val_acc: 0.128000
# (Iteration 11 / 40) loss: inf
# (Epoch 6 / 20) train acc: 0.180000; val_acc: 0.137000
# (Epoch 7 / 20) train acc: 0.120000; val_acc: 0.119000
# (Epoch 8 / 20) train acc: 0.120000; val_acc: 0.119000
# (Epoch 9 / 20) train acc: 0.120000; val_acc: 0.119000
# (Epoch 6 / 20) train acc: 0.180000; val_acc: 0.137000
# (Epoch 7 / 20) train acc: 0.120000; val_acc: 0.119000
# (Epoch 8 / 20) train acc: 0.120000; val_acc: 0.119000
# (Epoch 9 / 20) train acc: 0.120000; val_acc: 0.119000
# /Users/kiracoon/college/HDU-MTs/DeepLearning/assignment1/cs231n/classifiers/fc_net.py:360: RuntimeWarning: overflow encountered in square
#   reg_loss += np.sum(self.params[f"W{layer}"] ** 2)
# /Users/kiracoon/college/HDU-MTs/DeepLearning/assignment1/cs231n/classifiers/fc_net.py:361: RuntimeWarning: invalid value encountered in scalar multiply
#   loss += 0.5 * self.reg * reg_loss
# (Epoch 10 / 20) train acc: 0.120000; val_acc: 0.119000
# (Iteration 21 / 40) loss: nan
# (Epoch 11 / 20) train acc: 0.120000; val_acc: 0.119000
# (Epoch 12 / 20) train acc: 0.120000; val_acc: 0.119000
# (Epoch 13 / 20) train acc: 0.120000; val_acc: 0.119000
# (Epoch 14 / 20) train acc: 0.120000; val_acc: 0.119000
# (Epoch 15 / 20) train acc: 0.120000; val_acc: 0.119000
# (Iteration 31 / 40) loss: nan
# (Epoch 16 / 20) train acc: 0.120000; val_acc: 0.119000
# (Epoch 17 / 20) train acc: 0.120000; val_acc: 0.119000
# (Epoch 18 / 20) train acc: 0.120000; val_acc: 0.119000
# (Epoch 14 / 20) train acc: 0.120000; val_acc: 0.119000
# (Epoch 15 / 20) train acc: 0.120000; val_acc: 0.119000
# (Iteration 31 / 40) loss: nan
# (Epoch 16 / 20) train acc: 0.120000; val_acc: 0.119000
# (Epoch 17 / 20) train acc: 0.120000; val_acc: 0.119000
# (Epoch 18 / 20) train acc: 0.120000; val_acc: 0.119000
# (Epoch 19 / 20) train acc: 0.160000; val_acc: 0.079000
# (Epoch 20 / 20) train acc: 0.160000; val_acc: 0.079000
# weight_scale=3.00e-02, lr=7.50e-02, train_acc=0.1600, val_acc=0.0790
# (Iteration 1 / 40) loss: 5.496252
# (Epoch 0 / 20) train acc: 0.100000; val_acc: 0.107000
# (Epoch 1 / 20) train acc: 0.120000; val_acc: 0.105000
# (Epoch 19 / 20) train acc: 0.160000; val_acc: 0.079000
# (Epoch 20 / 20) train acc: 0.160000; val_acc: 0.079000
# weight_scale=3.00e-02, lr=7.50e-02, train_acc=0.1600, val_acc=0.0790
# (Iteration 1 / 40) loss: 5.496252
# (Epoch 0 / 20) train acc: 0.100000; val_acc: 0.107000
# (Epoch 1 / 20) train acc: 0.120000; val_acc: 0.105000
# (Epoch 2 / 20) train acc: 0.120000; val_acc: 0.073000
# (Epoch 3 / 20) train acc: 0.120000; val_acc: 0.120000
# (Epoch 4 / 20) train acc: 0.180000; val_acc: 0.128000
# (Epoch 5 / 20) train acc: 0.060000; val_acc: 0.038000
# (Iteration 11 / 40) loss: nan
# (Epoch 6 / 20) train acc: 0.080000; val_acc: 0.087000
# (Epoch 2 / 20) train acc: 0.120000; val_acc: 0.073000
# (Epoch 3 / 20) train acc: 0.120000; val_acc: 0.120000
# (Epoch 4 / 20) train acc: 0.180000; val_acc: 0.128000
# (Epoch 5 / 20) train acc: 0.060000; val_acc: 0.038000
# (Iteration 11 / 40) loss: nan
# (Epoch 6 / 20) train acc: 0.080000; val_acc: 0.087000
# /Users/kiracoon/college/HDU-MTs/DeepLearning/assignment1/cs231n/layers.py:907: RuntimeWarning: invalid value encountered in subtract
#   shifted = x - np.max(x, axis=1, keepdims=True)
# (Epoch 7 / 20) train acc: 0.080000; val_acc: 0.087000
# (Epoch 8 / 20) train acc: 0.080000; val_acc: 0.087000
# (Epoch 9 / 20) train acc: 0.080000; val_acc: 0.087000
# (Epoch 10 / 20) train acc: 0.080000; val_acc: 0.087000
# (Iteration 21 / 40) loss: nan
# (Epoch 11 / 20) train acc: 0.080000; val_acc: 0.087000
# (Epoch 12 / 20) train acc: 0.080000; val_acc: 0.087000
# (Epoch 13 / 20) train acc: 0.080000; val_acc: 0.087000
# (Epoch 14 / 20) train acc: 0.080000; val_acc: 0.087000
# (Epoch 12 / 20) train acc: 0.080000; val_acc: 0.087000
# (Epoch 13 / 20) train acc: 0.080000; val_acc: 0.087000
# (Epoch 14 / 20) train acc: 0.080000; val_acc: 0.087000
# (Epoch 15 / 20) train acc: 0.080000; val_acc: 0.087000
# (Iteration 31 / 40) loss: nan
# (Epoch 16 / 20) train acc: 0.080000; val_acc: 0.087000
# (Epoch 17 / 20) train acc: 0.080000; val_acc: 0.087000
# (Epoch 18 / 20) train acc: 0.080000; val_acc: 0.087000
# (Epoch 15 / 20) train acc: 0.080000; val_acc: 0.087000
# (Iteration 31 / 40) loss: nan
# (Epoch 16 / 20) train acc: 0.080000; val_acc: 0.087000
# (Epoch 17 / 20) train acc: 0.080000; val_acc: 0.087000
# (Epoch 18 / 20) train acc: 0.080000; val_acc: 0.087000
# (Epoch 19 / 20) train acc: 0.080000; val_acc: 0.087000
# (Epoch 20 / 20) train acc: 0.080000; val_acc: 0.087000
# weight_scale=3.00e-02, lr=1.00e-01, train_acc=0.0800, val_acc=0.0870
# (Iteration 1 / 40) loss: 8.505223
# (Epoch 0 / 20) train acc: 0.120000; val_acc: 0.119000
# (Epoch 1 / 20) train acc: 0.160000; val_acc: 0.079000
# (Epoch 2 / 20) train acc: 0.060000; val_acc: 0.092000
# (Epoch 19 / 20) train acc: 0.080000; val_acc: 0.087000
# (Epoch 20 / 20) train acc: 0.080000; val_acc: 0.087000
# weight_scale=3.00e-02, lr=1.00e-01, train_acc=0.0800, val_acc=0.0870
# (Iteration 1 / 40) loss: 8.505223
# (Epoch 0 / 20) train acc: 0.120000; val_acc: 0.119000
# (Epoch 1 / 20) train acc: 0.160000; val_acc: 0.079000
# (Epoch 2 / 20) train acc: 0.060000; val_acc: 0.092000
# (Epoch 3 / 20) train acc: 0.060000; val_acc: 0.085000
# (Epoch 4 / 20) train acc: 0.160000; val_acc: 0.128000
# (Epoch 5 / 20) train acc: 0.160000; val_acc: 0.079000
# (Iteration 11 / 40) loss: inf
# (Epoch 3 / 20) train acc: 0.060000; val_acc: 0.085000
# (Epoch 4 / 20) train acc: 0.160000; val_acc: 0.128000
# (Epoch 5 / 20) train acc: 0.160000; val_acc: 0.079000
# (Iteration 11 / 40) loss: inf
# (Epoch 6 / 20) train acc: 0.080000; val_acc: 0.087000
# (Epoch 7 / 20) train acc: 0.080000; val_acc: 0.087000
# (Epoch 8 / 20) train acc: 0.080000; val_acc: 0.087000
# (Epoch 9 / 20) train acc: 0.080000; val_acc: 0.087000
# (Epoch 10 / 20) train acc: 0.080000; val_acc: 0.087000
# (Iteration 21 / 40) loss: nan
# (Epoch 6 / 20) train acc: 0.080000; val_acc: 0.087000
# (Epoch 7 / 20) train acc: 0.080000; val_acc: 0.087000
# (Epoch 8 / 20) train acc: 0.080000; val_acc: 0.087000
# (Epoch 9 / 20) train acc: 0.080000; val_acc: 0.087000
# (Epoch 10 / 20) train acc: 0.080000; val_acc: 0.087000
# (Iteration 21 / 40) loss: nan
# (Epoch 11 / 20) train acc: 0.080000; val_acc: 0.087000
# (Epoch 12 / 20) train acc: 0.080000; val_acc: 0.087000
# (Epoch 13 / 20) train acc: 0.080000; val_acc: 0.087000
# (Epoch 11 / 20) train acc: 0.080000; val_acc: 0.087000
# (Epoch 12 / 20) train acc: 0.080000; val_acc: 0.087000
# (Epoch 13 / 20) train acc: 0.080000; val_acc: 0.087000
# (Epoch 14 / 20) train acc: 0.080000; val_acc: 0.087000
# (Epoch 15 / 20) train acc: 0.080000; val_acc: 0.087000
# (Iteration 31 / 40) loss: nan
# (Epoch 16 / 20) train acc: 0.080000; val_acc: 0.087000
# (Epoch 14 / 20) train acc: 0.080000; val_acc: 0.087000
# (Epoch 15 / 20) train acc: 0.080000; val_acc: 0.087000
# (Iteration 31 / 40) loss: nan
# (Epoch 16 / 20) train acc: 0.080000; val_acc: 0.087000
# (Epoch 17 / 20) train acc: 0.080000; val_acc: 0.087000
# (Epoch 18 / 20) train acc: 0.080000; val_acc: 0.087000
# (Epoch 19 / 20) train acc: 0.080000; val_acc: 0.087000
# (Epoch 20 / 20) train acc: 0.080000; val_acc: 0.087000
# weight_scale=3.00e-02, lr=1.50e-01, train_acc=0.0800, val_acc=0.0870
# (Iteration 1 / 40) loss: 35.159060
# (Epoch 0 / 20) train acc: 0.140000; val_acc: 0.093000
# (Epoch 17 / 20) train acc: 0.080000; val_acc: 0.087000
# (Epoch 18 / 20) train acc: 0.080000; val_acc: 0.087000
# (Epoch 19 / 20) train acc: 0.080000; val_acc: 0.087000
# (Epoch 20 / 20) train acc: 0.080000; val_acc: 0.087000
# weight_scale=3.00e-02, lr=1.50e-01, train_acc=0.0800, val_acc=0.0870
# (Iteration 1 / 40) loss: 35.159060
# (Epoch 0 / 20) train acc: 0.140000; val_acc: 0.093000
# (Epoch 1 / 20) train acc: 0.040000; val_acc: 0.098000
# (Epoch 2 / 20) train acc: 0.160000; val_acc: 0.112000
# (Epoch 3 / 20) train acc: 0.100000; val_acc: 0.087000
# (Epoch 1 / 20) train acc: 0.040000; val_acc: 0.098000
# (Epoch 2 / 20) train acc: 0.160000; val_acc: 0.112000
# (Epoch 3 / 20) train acc: 0.100000; val_acc: 0.087000
# (Epoch 4 / 20) train acc: 0.100000; val_acc: 0.085000
# (Epoch 5 / 20) train acc: 0.100000; val_acc: 0.085000
# (Iteration 11 / 40) loss: 2.303280
# (Epoch 6 / 20) train acc: 0.100000; val_acc: 0.085000
# (Epoch 4 / 20) train acc: 0.100000; val_acc: 0.085000
# (Epoch 5 / 20) train acc: 0.100000; val_acc: 0.085000
# (Iteration 11 / 40) loss: 2.303280
# (Epoch 6 / 20) train acc: 0.100000; val_acc: 0.085000
# (Epoch 7 / 20) train acc: 0.160000; val_acc: 0.119000
# (Epoch 8 / 20) train acc: 0.160000; val_acc: 0.085000
# (Epoch 9 / 20) train acc: 0.160000; val_acc: 0.085000
# (Epoch 10 / 20) train acc: 0.160000; val_acc: 0.085000
# (Iteration 21 / 40) loss: 2.292521
# (Epoch 7 / 20) train acc: 0.160000; val_acc: 0.119000
# (Epoch 8 / 20) train acc: 0.160000; val_acc: 0.085000
# (Epoch 9 / 20) train acc: 0.160000; val_acc: 0.085000
# (Epoch 10 / 20) train acc: 0.160000; val_acc: 0.085000
# (Iteration 21 / 40) loss: 2.292521
# (Epoch 11 / 20) train acc: 0.160000; val_acc: 0.119000
# (Epoch 12 / 20) train acc: 0.160000; val_acc: 0.119000
# (Epoch 13 / 20) train acc: 0.160000; val_acc: 0.119000
# (Epoch 14 / 20) train acc: 0.160000; val_acc: 0.085000
# (Epoch 11 / 20) train acc: 0.160000; val_acc: 0.119000
# (Epoch 12 / 20) train acc: 0.160000; val_acc: 0.119000
# (Epoch 13 / 20) train acc: 0.160000; val_acc: 0.119000
# (Epoch 14 / 20) train acc: 0.160000; val_acc: 0.085000
# (Epoch 15 / 20) train acc: 0.160000; val_acc: 0.085000
# (Iteration 31 / 40) loss: 2.276501
# (Epoch 16 / 20) train acc: 0.160000; val_acc: 0.119000
# (Epoch 17 / 20) train acc: 0.160000; val_acc: 0.119000
# (Epoch 18 / 20) train acc: 0.160000; val_acc: 0.119000
# (Epoch 15 / 20) train acc: 0.160000; val_acc: 0.085000
# (Iteration 31 / 40) loss: 2.276501
# (Epoch 16 / 20) train acc: 0.160000; val_acc: 0.119000
# (Epoch 17 / 20) train acc: 0.160000; val_acc: 0.119000
# (Epoch 18 / 20) train acc: 0.160000; val_acc: 0.119000
# (Epoch 19 / 20) train acc: 0.160000; val_acc: 0.119000
# (Epoch 20 / 20) train acc: 0.160000; val_acc: 0.119000
# weight_scale=5.00e-02, lr=5.00e-02, train_acc=0.1600, val_acc=0.1190
# (Iteration 1 / 40) loss: 28.400076
# (Epoch 0 / 20) train acc: 0.160000; val_acc: 0.112000
# (Epoch 1 / 20) train acc: 0.100000; val_acc: 0.089000
# (Epoch 19 / 20) train acc: 0.160000; val_acc: 0.119000
# (Epoch 20 / 20) train acc: 0.160000; val_acc: 0.119000
# weight_scale=5.00e-02, lr=5.00e-02, train_acc=0.1600, val_acc=0.1190
# (Iteration 1 / 40) loss: 28.400076
# (Epoch 0 / 20) train acc: 0.160000; val_acc: 0.112000
# (Epoch 1 / 20) train acc: 0.100000; val_acc: 0.089000
# (Epoch 2 / 20) train acc: 0.160000; val_acc: 0.109000
# (Epoch 3 / 20) train acc: 0.160000; val_acc: 0.079000
# (Epoch 4 / 20) train acc: 0.080000; val_acc: 0.087000
# (Epoch 5 / 20) train acc: 0.100000; val_acc: 0.066000
# (Iteration 11 / 40) loss: nan
# (Epoch 6 / 20) train acc: 0.080000; val_acc: 0.087000
# (Epoch 2 / 20) train acc: 0.160000; val_acc: 0.109000
# (Epoch 3 / 20) train acc: 0.160000; val_acc: 0.079000
# (Epoch 4 / 20) train acc: 0.080000; val_acc: 0.087000
# (Epoch 5 / 20) train acc: 0.100000; val_acc: 0.066000
# (Iteration 11 / 40) loss: nan
# (Epoch 6 / 20) train acc: 0.080000; val_acc: 0.087000
# (Epoch 7 / 20) train acc: 0.080000; val_acc: 0.087000
# (Epoch 8 / 20) train acc: 0.080000; val_acc: 0.087000
# (Epoch 9 / 20) train acc: 0.080000; val_acc: 0.087000
# (Epoch 7 / 20) train acc: 0.080000; val_acc: 0.087000
# (Epoch 8 / 20) train acc: 0.080000; val_acc: 0.087000
# (Epoch 9 / 20) train acc: 0.080000; val_acc: 0.087000
# (Epoch 10 / 20) train acc: 0.080000; val_acc: 0.087000
# (Iteration 21 / 40) loss: nan
# (Epoch 11 / 20) train acc: 0.080000; val_acc: 0.087000
# (Epoch 12 / 20) train acc: 0.080000; val_acc: 0.087000
# (Epoch 10 / 20) train acc: 0.080000; val_acc: 0.087000
# (Iteration 21 / 40) loss: nan
# (Epoch 11 / 20) train acc: 0.080000; val_acc: 0.087000
# (Epoch 12 / 20) train acc: 0.080000; val_acc: 0.087000
# (Epoch 13 / 20) train acc: 0.080000; val_acc: 0.087000
# (Epoch 14 / 20) train acc: 0.080000; val_acc: 0.087000
# (Epoch 15 / 20) train acc: 0.080000; val_acc: 0.087000
# (Iteration 31 / 40) loss: nan
# (Epoch 16 / 20) train acc: 0.080000; val_acc: 0.087000
# (Epoch 17 / 20) train acc: 0.080000; val_acc: 0.087000
# (Epoch 13 / 20) train acc: 0.080000; val_acc: 0.087000
# (Epoch 14 / 20) train acc: 0.080000; val_acc: 0.087000
# (Epoch 15 / 20) train acc: 0.080000; val_acc: 0.087000
# (Iteration 31 / 40) loss: nan
# (Epoch 16 / 20) train acc: 0.080000; val_acc: 0.087000
# (Epoch 17 / 20) train acc: 0.080000; val_acc: 0.087000
# (Epoch 18 / 20) train acc: 0.080000; val_acc: 0.087000
# (Epoch 19 / 20) train acc: 0.080000; val_acc: 0.087000
# (Epoch 20 / 20) train acc: 0.080000; val_acc: 0.087000
# weight_scale=5.00e-02, lr=7.50e-02, train_acc=0.0800, val_acc=0.0870
# (Iteration 1 / 40) loss: 28.584835
# (Epoch 0 / 20) train acc: 0.100000; val_acc: 0.078000
# (Epoch 18 / 20) train acc: 0.080000; val_acc: 0.087000
# (Epoch 19 / 20) train acc: 0.080000; val_acc: 0.087000
# (Epoch 20 / 20) train acc: 0.080000; val_acc: 0.087000
# weight_scale=5.00e-02, lr=7.50e-02, train_acc=0.0800, val_acc=0.0870
# (Iteration 1 / 40) loss: 28.584835
# (Epoch 0 / 20) train acc: 0.100000; val_acc: 0.078000
# (Epoch 1 / 20) train acc: 0.160000; val_acc: 0.112000
# (Epoch 2 / 20) train acc: 0.160000; val_acc: 0.084000
# (Epoch 3 / 20) train acc: 0.080000; val_acc: 0.108000
# (Epoch 4 / 20) train acc: 0.080000; val_acc: 0.100000
# (Epoch 1 / 20) train acc: 0.160000; val_acc: 0.112000
# (Epoch 2 / 20) train acc: 0.160000; val_acc: 0.084000
# (Epoch 3 / 20) train acc: 0.080000; val_acc: 0.108000
# (Epoch 4 / 20) train acc: 0.080000; val_acc: 0.100000
# (Epoch 5 / 20) train acc: 0.080000; val_acc: 0.108000
# (Iteration 11 / 40) loss: inf
# (Epoch 6 / 20) train acc: 0.100000; val_acc: 0.107000
# (Epoch 7 / 20) train acc: 0.080000; val_acc: 0.087000
# (Epoch 8 / 20) train acc: 0.080000; val_acc: 0.087000
# (Epoch 5 / 20) train acc: 0.080000; val_acc: 0.108000
# (Iteration 11 / 40) loss: inf
# (Epoch 6 / 20) train acc: 0.100000; val_acc: 0.107000
# (Epoch 7 / 20) train acc: 0.080000; val_acc: 0.087000
# (Epoch 8 / 20) train acc: 0.080000; val_acc: 0.087000
# (Epoch 9 / 20) train acc: 0.080000; val_acc: 0.087000
# (Epoch 10 / 20) train acc: 0.080000; val_acc: 0.087000
# (Iteration 21 / 40) loss: nan
# (Epoch 11 / 20) train acc: 0.080000; val_acc: 0.087000
# (Epoch 12 / 20) train acc: 0.080000; val_acc: 0.087000
# (Epoch 9 / 20) train acc: 0.080000; val_acc: 0.087000
# (Epoch 10 / 20) train acc: 0.080000; val_acc: 0.087000
# (Iteration 21 / 40) loss: nan
# (Epoch 11 / 20) train acc: 0.080000; val_acc: 0.087000
# (Epoch 12 / 20) train acc: 0.080000; val_acc: 0.087000
# (Epoch 13 / 20) train acc: 0.080000; val_acc: 0.087000
# (Epoch 14 / 20) train acc: 0.080000; val_acc: 0.087000
# (Epoch 15 / 20) train acc: 0.080000; val_acc: 0.087000
# (Iteration 31 / 40) loss: nan
# (Epoch 16 / 20) train acc: 0.080000; val_acc: 0.087000
# (Epoch 17 / 20) train acc: 0.080000; val_acc: 0.087000
# (Epoch 13 / 20) train acc: 0.080000; val_acc: 0.087000
# (Epoch 14 / 20) train acc: 0.080000; val_acc: 0.087000
# (Epoch 15 / 20) train acc: 0.080000; val_acc: 0.087000
# (Iteration 31 / 40) loss: nan
# (Epoch 16 / 20) train acc: 0.080000; val_acc: 0.087000
# (Epoch 17 / 20) train acc: 0.080000; val_acc: 0.087000
# (Epoch 18 / 20) train acc: 0.080000; val_acc: 0.087000
# (Epoch 19 / 20) train acc: 0.080000; val_acc: 0.087000
# (Epoch 20 / 20) train acc: 0.080000; val_acc: 0.087000
# weight_scale=5.00e-02, lr=1.00e-01, train_acc=0.0800, val_acc=0.0870
# (Iteration 1 / 40) loss: 28.158169
# (Epoch 0 / 20) train acc: 0.160000; val_acc: 0.079000
# (Epoch 18 / 20) train acc: 0.080000; val_acc: 0.087000
# (Epoch 19 / 20) train acc: 0.080000; val_acc: 0.087000
# (Epoch 20 / 20) train acc: 0.080000; val_acc: 0.087000
# weight_scale=5.00e-02, lr=1.00e-01, train_acc=0.0800, val_acc=0.0870
# (Iteration 1 / 40) loss: 28.158169
# (Epoch 0 / 20) train acc: 0.160000; val_acc: 0.079000
# (Epoch 1 / 20) train acc: 0.120000; val_acc: 0.105000
# (Epoch 2 / 20) train acc: 0.160000; val_acc: 0.121000
# (Epoch 3 / 20) train acc: 0.140000; val_acc: 0.084000
# (Epoch 4 / 20) train acc: 0.100000; val_acc: 0.104000
# (Epoch 5 / 20) train acc: 0.140000; val_acc: 0.086000
# (Iteration 11 / 40) loss: inf
# (Epoch 1 / 20) train acc: 0.120000; val_acc: 0.105000
# (Epoch 2 / 20) train acc: 0.160000; val_acc: 0.121000
# (Epoch 3 / 20) train acc: 0.140000; val_acc: 0.084000
# (Epoch 4 / 20) train acc: 0.100000; val_acc: 0.104000
# (Epoch 5 / 20) train acc: 0.140000; val_acc: 0.086000
# (Iteration 11 / 40) loss: inf
# (Epoch 6 / 20) train acc: 0.080000; val_acc: 0.087000
# (Epoch 7 / 20) train acc: 0.080000; val_acc: 0.087000
# (Epoch 8 / 20) train acc: 0.080000; val_acc: 0.087000
# (Epoch 9 / 20) train acc: 0.080000; val_acc: 0.087000
# (Epoch 10 / 20) train acc: 0.080000; val_acc: 0.087000
# (Iteration 21 / 40) loss: nan
# (Epoch 6 / 20) train acc: 0.080000; val_acc: 0.087000
# (Epoch 7 / 20) train acc: 0.080000; val_acc: 0.087000
# (Epoch 8 / 20) train acc: 0.080000; val_acc: 0.087000
# (Epoch 9 / 20) train acc: 0.080000; val_acc: 0.087000
# (Epoch 10 / 20) train acc: 0.080000; val_acc: 0.087000
# (Iteration 21 / 40) loss: nan
# (Epoch 11 / 20) train acc: 0.080000; val_acc: 0.087000
# (Epoch 12 / 20) train acc: 0.080000; val_acc: 0.087000
# (Epoch 13 / 20) train acc: 0.080000; val_acc: 0.087000
# (Epoch 14 / 20) train acc: 0.080000; val_acc: 0.087000
# (Epoch 11 / 20) train acc: 0.080000; val_acc: 0.087000
# (Epoch 12 / 20) train acc: 0.080000; val_acc: 0.087000
# (Epoch 13 / 20) train acc: 0.080000; val_acc: 0.087000
# (Epoch 14 / 20) train acc: 0.080000; val_acc: 0.087000
# (Epoch 15 / 20) train acc: 0.080000; val_acc: 0.087000
# (Iteration 31 / 40) loss: nan
# (Epoch 16 / 20) train acc: 0.080000; val_acc: 0.087000
# (Epoch 17 / 20) train acc: 0.080000; val_acc: 0.087000
# (Epoch 18 / 20) train acc: 0.080000; val_acc: 0.087000
# (Epoch 15 / 20) train acc: 0.080000; val_acc: 0.087000
# (Iteration 31 / 40) loss: nan
# (Epoch 16 / 20) train acc: 0.080000; val_acc: 0.087000
# (Epoch 17 / 20) train acc: 0.080000; val_acc: 0.087000
# (Epoch 18 / 20) train acc: 0.080000; val_acc: 0.087000
# (Epoch 19 / 20) train acc: 0.080000; val_acc: 0.087000
# (Epoch 20 / 20) train acc: 0.080000; val_acc: 0.087000
# weight_scale=5.00e-02, lr=1.50e-01, train_acc=0.0800, val_acc=0.0870
# (Iteration 1 / 40) loss: 94.933419
# (Epoch 0 / 20) train acc: 0.160000; val_acc: 0.079000
# (Epoch 19 / 20) train acc: 0.080000; val_acc: 0.087000
# (Epoch 20 / 20) train acc: 0.080000; val_acc: 0.087000
# weight_scale=5.00e-02, lr=1.50e-01, train_acc=0.0800, val_acc=0.0870
# (Iteration 1 / 40) loss: 94.933419
# (Epoch 0 / 20) train acc: 0.160000; val_acc: 0.079000
# (Epoch 1 / 20) train acc: 0.100000; val_acc: 0.078000
# (Epoch 2 / 20) train acc: 0.120000; val_acc: 0.105000
# (Epoch 3 / 20) train acc: 0.120000; val_acc: 0.114000
# (Epoch 1 / 20) train acc: 0.100000; val_acc: 0.078000
# (Epoch 2 / 20) train acc: 0.120000; val_acc: 0.105000
# (Epoch 3 / 20) train acc: 0.120000; val_acc: 0.114000
# (Epoch 4 / 20) train acc: 0.060000; val_acc: 0.087000
# (Epoch 5 / 20) train acc: 0.100000; val_acc: 0.102000
# (Iteration 11 / 40) loss: 2.302262
# (Epoch 6 / 20) train acc: 0.100000; val_acc: 0.102000
# (Epoch 4 / 20) train acc: 0.060000; val_acc: 0.087000
# (Epoch 5 / 20) train acc: 0.100000; val_acc: 0.102000
# (Iteration 11 / 40) loss: 2.302262
# (Epoch 6 / 20) train acc: 0.100000; val_acc: 0.102000
# (Epoch 7 / 20) train acc: 0.100000; val_acc: 0.102000
# (Epoch 8 / 20) train acc: 0.120000; val_acc: 0.119000
# (Epoch 9 / 20) train acc: 0.120000; val_acc: 0.119000
# (Epoch 10 / 20) train acc: 0.120000; val_acc: 0.119000
# (Epoch 7 / 20) train acc: 0.100000; val_acc: 0.102000
# (Epoch 8 / 20) train acc: 0.120000; val_acc: 0.119000
# (Epoch 9 / 20) train acc: 0.120000; val_acc: 0.119000
# (Epoch 10 / 20) train acc: 0.120000; val_acc: 0.119000
# (Iteration 21 / 40) loss: 2.292316
# (Epoch 11 / 20) train acc: 0.160000; val_acc: 0.079000
# (Epoch 12 / 20) train acc: 0.160000; val_acc: 0.079000
# (Epoch 13 / 20) train acc: 0.160000; val_acc: 0.079000
# (Iteration 21 / 40) loss: 2.292316
# (Epoch 11 / 20) train acc: 0.160000; val_acc: 0.079000
# (Epoch 12 / 20) train acc: 0.160000; val_acc: 0.079000
# (Epoch 13 / 20) train acc: 0.160000; val_acc: 0.079000
# (Epoch 14 / 20) train acc: 0.160000; val_acc: 0.079000
# (Epoch 15 / 20) train acc: 0.160000; val_acc: 0.079000
# (Iteration 31 / 40) loss: 2.289503
# (Epoch 16 / 20) train acc: 0.160000; val_acc: 0.079000
# (Epoch 14 / 20) train acc: 0.160000; val_acc: 0.079000
# (Epoch 15 / 20) train acc: 0.160000; val_acc: 0.079000
# (Iteration 31 / 40) loss: 2.289503
# (Epoch 16 / 20) train acc: 0.160000; val_acc: 0.079000
# (Epoch 17 / 20) train acc: 0.160000; val_acc: 0.079000
# (Epoch 18 / 20) train acc: 0.160000; val_acc: 0.079000
# (Epoch 19 / 20) train acc: 0.160000; val_acc: 0.079000
# (Epoch 20 / 20) train acc: 0.160000; val_acc: 0.079000
# weight_scale=7.00e-02, lr=5.00e-02, train_acc=0.1600, val_acc=0.0790
# (Iteration 1 / 40) loss: 128.547779
# (Epoch 0 / 20) train acc: 0.160000; val_acc: 0.079000
# (Epoch 17 / 20) train acc: 0.160000; val_acc: 0.079000
# (Epoch 18 / 20) train acc: 0.160000; val_acc: 0.079000
# (Epoch 19 / 20) train acc: 0.160000; val_acc: 0.079000
# (Epoch 20 / 20) train acc: 0.160000; val_acc: 0.079000
# weight_scale=7.00e-02, lr=5.00e-02, train_acc=0.1600, val_acc=0.0790
# (Iteration 1 / 40) loss: 128.547779
# (Epoch 0 / 20) train acc: 0.160000; val_acc: 0.079000
# (Epoch 1 / 20) train acc: 0.160000; val_acc: 0.112000
# (Epoch 2 / 20) train acc: 0.160000; val_acc: 0.118000
# (Epoch 3 / 20) train acc: 0.080000; val_acc: 0.088000
# (Epoch 4 / 20) train acc: 0.140000; val_acc: 0.107000
# (Epoch 1 / 20) train acc: 0.160000; val_acc: 0.112000
# (Epoch 2 / 20) train acc: 0.160000; val_acc: 0.118000
# (Epoch 3 / 20) train acc: 0.080000; val_acc: 0.088000
# (Epoch 4 / 20) train acc: 0.140000; val_acc: 0.107000
# (Epoch 5 / 20) train acc: 0.120000; val_acc: 0.117000
# (Iteration 11 / 40) loss: nan
# (Epoch 6 / 20) train acc: 0.080000; val_acc: 0.087000
# (Epoch 7 / 20) train acc: 0.080000; val_acc: 0.087000
# (Epoch 5 / 20) train acc: 0.120000; val_acc: 0.117000
# (Iteration 11 / 40) loss: nan
# (Epoch 6 / 20) train acc: 0.080000; val_acc: 0.087000
# (Epoch 7 / 20) train acc: 0.080000; val_acc: 0.087000
# (Epoch 8 / 20) train acc: 0.080000; val_acc: 0.087000
# (Epoch 9 / 20) train acc: 0.080000; val_acc: 0.087000
# (Epoch 10 / 20) train acc: 0.080000; val_acc: 0.087000
# (Iteration 21 / 40) loss: nan
# (Epoch 11 / 20) train acc: 0.080000; val_acc: 0.087000
# (Epoch 8 / 20) train acc: 0.080000; val_acc: 0.087000
# (Epoch 9 / 20) train acc: 0.080000; val_acc: 0.087000
# (Epoch 10 / 20) train acc: 0.080000; val_acc: 0.087000
# (Iteration 21 / 40) loss: nan
# (Epoch 11 / 20) train acc: 0.080000; val_acc: 0.087000
# (Epoch 12 / 20) train acc: 0.080000; val_acc: 0.087000
# (Epoch 13 / 20) train acc: 0.080000; val_acc: 0.087000
# (Epoch 14 / 20) train acc: 0.080000; val_acc: 0.087000
# (Epoch 12 / 20) train acc: 0.080000; val_acc: 0.087000
# (Epoch 13 / 20) train acc: 0.080000; val_acc: 0.087000
# (Epoch 14 / 20) train acc: 0.080000; val_acc: 0.087000
# (Epoch 15 / 20) train acc: 0.080000; val_acc: 0.087000
# (Iteration 31 / 40) loss: nan
# (Epoch 16 / 20) train acc: 0.080000; val_acc: 0.087000
# (Epoch 17 / 20) train acc: 0.080000; val_acc: 0.087000
# (Epoch 15 / 20) train acc: 0.080000; val_acc: 0.087000
# (Iteration 31 / 40) loss: nan
# (Epoch 16 / 20) train acc: 0.080000; val_acc: 0.087000
# (Epoch 17 / 20) train acc: 0.080000; val_acc: 0.087000
# (Epoch 18 / 20) train acc: 0.080000; val_acc: 0.087000
# (Epoch 19 / 20) train acc: 0.080000; val_acc: 0.087000
# (Epoch 20 / 20) train acc: 0.080000; val_acc: 0.087000
# weight_scale=7.00e-02, lr=7.50e-02, train_acc=0.0800, val_acc=0.0870
# (Iteration 1 / 40) loss: 85.499461
# (Epoch 18 / 20) train acc: 0.080000; val_acc: 0.087000
# (Epoch 19 / 20) train acc: 0.080000; val_acc: 0.087000
# (Epoch 20 / 20) train acc: 0.080000; val_acc: 0.087000
# weight_scale=7.00e-02, lr=7.50e-02, train_acc=0.0800, val_acc=0.0870
# (Iteration 1 / 40) loss: 85.499461
# (Epoch 0 / 20) train acc: 0.160000; val_acc: 0.112000
# (Epoch 1 / 20) train acc: 0.100000; val_acc: 0.102000
# (Epoch 0 / 20) train acc: 0.160000; val_acc: 0.112000
# (Epoch 1 / 20) train acc: 0.100000; val_acc: 0.102000
# (Epoch 2 / 20) train acc: 0.160000; val_acc: 0.112000
# (Epoch 3 / 20) train acc: 0.040000; val_acc: 0.101000
# (Epoch 4 / 20) train acc: 0.140000; val_acc: 0.086000
# (Epoch 2 / 20) train acc: 0.160000; val_acc: 0.112000
# (Epoch 3 / 20) train acc: 0.040000; val_acc: 0.101000
# (Epoch 4 / 20) train acc: 0.140000; val_acc: 0.086000
# (Epoch 5 / 20) train acc: 0.060000; val_acc: 0.103000
# (Iteration 11 / 40) loss: inf
# (Epoch 6 / 20) train acc: 0.120000; val_acc: 0.105000
# (Epoch 7 / 20) train acc: 0.120000; val_acc: 0.105000
# (Epoch 8 / 20) train acc: 0.120000; val_acc: 0.105000
# (Epoch 5 / 20) train acc: 0.060000; val_acc: 0.103000
# (Iteration 11 / 40) loss: inf
# (Epoch 6 / 20) train acc: 0.120000; val_acc: 0.105000
# (Epoch 7 / 20) train acc: 0.120000; val_acc: 0.105000
# (Epoch 8 / 20) train acc: 0.120000; val_acc: 0.105000
# (Epoch 9 / 20) train acc: 0.120000; val_acc: 0.105000
# (Epoch 10 / 20) train acc: 0.120000; val_acc: 0.105000
# (Iteration 21 / 40) loss: 2.284775
# (Epoch 11 / 20) train acc: 0.120000; val_acc: 0.105000
# (Epoch 12 / 20) train acc: 0.120000; val_acc: 0.105000
# (Epoch 9 / 20) train acc: 0.120000; val_acc: 0.105000
# (Epoch 10 / 20) train acc: 0.120000; val_acc: 0.105000
# (Iteration 21 / 40) loss: 2.284775
# (Epoch 11 / 20) train acc: 0.120000; val_acc: 0.105000
# (Epoch 12 / 20) train acc: 0.120000; val_acc: 0.105000
# (Epoch 13 / 20) train acc: 0.120000; val_acc: 0.105000
# (Epoch 14 / 20) train acc: 0.160000; val_acc: 0.079000
# (Epoch 15 / 20) train acc: 0.160000; val_acc: 0.079000
# (Iteration 31 / 40) loss: 2.245698
# (Epoch 16 / 20) train acc: 0.160000; val_acc: 0.079000
# (Epoch 13 / 20) train acc: 0.120000; val_acc: 0.105000
# (Epoch 14 / 20) train acc: 0.160000; val_acc: 0.079000
# (Epoch 15 / 20) train acc: 0.160000; val_acc: 0.079000
# (Iteration 31 / 40) loss: 2.245698
# (Epoch 16 / 20) train acc: 0.160000; val_acc: 0.079000
# (Epoch 17 / 20) train acc: 0.160000; val_acc: 0.079000
# (Epoch 18 / 20) train acc: 0.160000; val_acc: 0.079000
# (Epoch 19 / 20) train acc: 0.160000; val_acc: 0.079000
# (Epoch 17 / 20) train acc: 0.160000; val_acc: 0.079000
# (Epoch 18 / 20) train acc: 0.160000; val_acc: 0.079000
# (Epoch 19 / 20) train acc: 0.160000; val_acc: 0.079000
# (Epoch 20 / 20) train acc: 0.160000; val_acc: 0.079000
# weight_scale=7.00e-02, lr=1.00e-01, train_acc=0.1600, val_acc=0.0790
# (Iteration 1 / 40) loss: 71.441819
# (Epoch 0 / 20) train acc: 0.160000; val_acc: 0.079000
# (Epoch 1 / 20) train acc: 0.100000; val_acc: 0.076000
# (Epoch 2 / 20) train acc: 0.080000; val_acc: 0.087000
# (Epoch 3 / 20) train acc: 0.080000; val_acc: 0.102000
# (Epoch 20 / 20) train acc: 0.160000; val_acc: 0.079000
# weight_scale=7.00e-02, lr=1.00e-01, train_acc=0.1600, val_acc=0.0790
# (Iteration 1 / 40) loss: 71.441819
# (Epoch 0 / 20) train acc: 0.160000; val_acc: 0.079000
# (Epoch 1 / 20) train acc: 0.100000; val_acc: 0.076000
# (Epoch 2 / 20) train acc: 0.080000; val_acc: 0.087000
# (Epoch 3 / 20) train acc: 0.080000; val_acc: 0.102000
# (Epoch 4 / 20) train acc: 0.120000; val_acc: 0.119000
# (Epoch 5 / 20) train acc: 0.100000; val_acc: 0.107000
# (Iteration 11 / 40) loss: inf
# (Epoch 6 / 20) train acc: 0.200000; val_acc: 0.128000
# (Epoch 7 / 20) train acc: 0.200000; val_acc: 0.102000
# (Epoch 4 / 20) train acc: 0.120000; val_acc: 0.119000
# (Epoch 5 / 20) train acc: 0.100000; val_acc: 0.107000
# (Iteration 11 / 40) loss: inf
# (Epoch 6 / 20) train acc: 0.200000; val_acc: 0.128000
# (Epoch 7 / 20) train acc: 0.200000; val_acc: 0.102000
# (Epoch 8 / 20) train acc: 0.120000; val_acc: 0.119000
# (Epoch 9 / 20) train acc: 0.120000; val_acc: 0.119000
# (Epoch 10 / 20) train acc: 0.120000; val_acc: 0.119000
# (Iteration 21 / 40) loss: 2.319033
# (Epoch 8 / 20) train acc: 0.120000; val_acc: 0.119000
# (Epoch 9 / 20) train acc: 0.120000; val_acc: 0.119000
# (Epoch 10 / 20) train acc: 0.120000; val_acc: 0.119000
# (Iteration 21 / 40) loss: 2.319033
# (Epoch 11 / 20) train acc: 0.120000; val_acc: 0.119000
# (Epoch 12 / 20) train acc: 0.120000; val_acc: 0.119000
# (Epoch 13 / 20) train acc: 0.120000; val_acc: 0.119000
# (Epoch 14 / 20) train acc: 0.120000; val_acc: 0.119000
# (Epoch 11 / 20) train acc: 0.120000; val_acc: 0.119000
# (Epoch 12 / 20) train acc: 0.120000; val_acc: 0.119000
# (Epoch 13 / 20) train acc: 0.120000; val_acc: 0.119000
# (Epoch 14 / 20) train acc: 0.120000; val_acc: 0.119000
# (Epoch 15 / 20) train acc: 0.120000; val_acc: 0.119000
# (Iteration 31 / 40) loss: 2.274021
# (Epoch 16 / 20) train acc: 0.120000; val_acc: 0.119000
# (Epoch 15 / 20) train acc: 0.120000; val_acc: 0.119000
# (Iteration 31 / 40) loss: 2.274021
# (Epoch 16 / 20) train acc: 0.120000; val_acc: 0.119000
# (Epoch 17 / 20) train acc: 0.160000; val_acc: 0.112000
# (Epoch 18 / 20) train acc: 0.160000; val_acc: 0.112000
# (Epoch 19 / 20) train acc: 0.160000; val_acc: 0.112000
# (Epoch 17 / 20) train acc: 0.160000; val_acc: 0.112000
# (Epoch 18 / 20) train acc: 0.160000; val_acc: 0.112000
# (Epoch 19 / 20) train acc: 0.160000; val_acc: 0.112000
# (Epoch 20 / 20) train acc: 0.160000; val_acc: 0.112000
# weight_scale=7.00e-02, lr=1.50e-01, train_acc=0.1600, val_acc=0.1120
# 最佳三层网络配置: {'weight_scale': 0.03, 'learning_rate': 0.05}
# (Epoch 20 / 20) train acc: 0.160000; val_acc: 0.112000
# weight_scale=7.00e-02, lr=1.50e-01, train_acc=0.1600, val_acc=0.1120
# 最佳三层网络配置: {'weight_scale': 0.03, 'learning_rate': 0.05}

# %% [markdown]
# Now, try to use a five-layer network with 100 units on each layer to overfit on 50 training examples. Again, you will have to adjust the learning rate and weight initialization scale, but you should be able to achieve 100% training accuracy within 20 epochs.

# %%
# TODO: Use a five-layer Net to overfit 50 training examples by
# tweaking just the learning rate and initialization scale.

num_train = 50
small_data = {
  'X_train': data['X_train'][:num_train],
  'y_train': data['y_train'][:num_train],
  'X_val': data['X_val'],
  'y_val': data['y_val'],
}

learning_rate_candidates = [3e-2, 5e-2, 7e-2, 1e-1]
weight_scale_candidates = [2e-2, 3e-2, 5e-2]

overfit_target = 0.999
best_solver_5layer = None
best_stats_5layer = None
best_train_acc = -1

for weight_scale in weight_scale_candidates:
    for learning_rate in learning_rate_candidates:
        model = FullyConnectedNet(
            [100, 100, 100, 100],
            weight_scale=weight_scale,
            dtype=np.float64
        )
        solver = Solver(
            model,
            small_data,
            print_every=10,
            num_epochs=20,
            batch_size=25,
            update_rule='sgd',
            optim_config={'learning_rate': learning_rate},
        )
        solver.train()
        train_acc = solver.train_acc_history[-1]
        val_acc = solver.val_acc_history[-1]
        print(f"weight_scale={weight_scale:.2e}, lr={learning_rate:.2e}, train_acc={train_acc:.4f}, val_acc={val_acc:.4f}")
        if train_acc > best_train_acc:
            best_train_acc = train_acc
            best_solver_5layer = solver
            best_stats_5layer = {
                'weight_scale': weight_scale,
                'learning_rate': learning_rate,
            }
        if train_acc >= overfit_target:
            break
    if best_train_acc >= overfit_target:
        break

solver = best_solver_5layer
print("最佳五层网络配置:", best_stats_5layer)
plt.plot(solver.loss_history)
plt.title("Training loss history (best 5-layer net)")
plt.xlabel("Iteration")
plt.ylabel("Training loss")
plt.grid(linestyle='--', linewidth=0.5)
plt.show()
# Out:
# (Iteration 1 / 40) loss: 2.307565
# (Epoch 0 / 20) train acc: 0.160000; val_acc: 0.123000
# (Epoch 1 / 20) train acc: 0.160000; val_acc: 0.124000
# (Epoch 2 / 20) train acc: 0.180000; val_acc: 0.121000
# (Epoch 3 / 20) train acc: 0.180000; val_acc: 0.112000
# (Epoch 4 / 20) train acc: 0.160000; val_acc: 0.112000
# (Epoch 5 / 20) train acc: 0.160000; val_acc: 0.112000
# (Iteration 11 / 40) loss: 2.246813
# (Epoch 6 / 20) train acc: 0.180000; val_acc: 0.112000
# (Epoch 3 / 20) train acc: 0.180000; val_acc: 0.112000
# (Epoch 4 / 20) train acc: 0.160000; val_acc: 0.112000
# (Epoch 5 / 20) train acc: 0.160000; val_acc: 0.112000
# (Iteration 11 / 40) loss: 2.246813
# (Epoch 6 / 20) train acc: 0.180000; val_acc: 0.112000
# (Epoch 7 / 20) train acc: 0.160000; val_acc: 0.112000
# (Epoch 8 / 20) train acc: 0.160000; val_acc: 0.112000
# (Epoch 9 / 20) train acc: 0.160000; val_acc: 0.112000
# (Epoch 7 / 20) train acc: 0.160000; val_acc: 0.112000
# (Epoch 8 / 20) train acc: 0.160000; val_acc: 0.112000
# (Epoch 9 / 20) train acc: 0.160000; val_acc: 0.112000
# (Epoch 10 / 20) train acc: 0.160000; val_acc: 0.112000
# (Iteration 21 / 40) loss: 2.138128
# (Epoch 11 / 20) train acc: 0.160000; val_acc: 0.112000
# (Epoch 12 / 20) train acc: 0.240000; val_acc: 0.118000
# (Epoch 13 / 20) train acc: 0.380000; val_acc: 0.116000
# (Epoch 10 / 20) train acc: 0.160000; val_acc: 0.112000
# (Iteration 21 / 40) loss: 2.138128
# (Epoch 11 / 20) train acc: 0.160000; val_acc: 0.112000
# (Epoch 12 / 20) train acc: 0.240000; val_acc: 0.118000
# (Epoch 13 / 20) train acc: 0.380000; val_acc: 0.116000
# (Epoch 14 / 20) train acc: 0.420000; val_acc: 0.094000
# (Epoch 15 / 20) train acc: 0.480000; val_acc: 0.133000
# (Iteration 31 / 40) loss: 2.165574
# (Epoch 16 / 20) train acc: 0.500000; val_acc: 0.165000
# (Epoch 14 / 20) train acc: 0.420000; val_acc: 0.094000
# (Epoch 15 / 20) train acc: 0.480000; val_acc: 0.133000
# (Iteration 31 / 40) loss: 2.165574
# (Epoch 16 / 20) train acc: 0.500000; val_acc: 0.165000
# (Epoch 17 / 20) train acc: 0.600000; val_acc: 0.150000
# (Epoch 18 / 20) train acc: 0.360000; val_acc: 0.140000
# (Epoch 19 / 20) train acc: 0.320000; val_acc: 0.119000
# (Epoch 20 / 20) train acc: 0.540000; val_acc: 0.162000
# weight_scale=2.00e-02, lr=3.00e-02, train_acc=0.5400, val_acc=0.1620
# (Iteration 1 / 40) loss: 2.304866
# (Epoch 17 / 20) train acc: 0.600000; val_acc: 0.150000
# (Epoch 18 / 20) train acc: 0.360000; val_acc: 0.140000
# (Epoch 19 / 20) train acc: 0.320000; val_acc: 0.119000
# (Epoch 20 / 20) train acc: 0.540000; val_acc: 0.162000
# weight_scale=2.00e-02, lr=3.00e-02, train_acc=0.5400, val_acc=0.1620
# (Iteration 1 / 40) loss: 2.304866
# (Epoch 0 / 20) train acc: 0.140000; val_acc: 0.108000
# (Epoch 1 / 20) train acc: 0.280000; val_acc: 0.095000
# (Epoch 2 / 20) train acc: 0.280000; val_acc: 0.091000
# (Epoch 0 / 20) train acc: 0.140000; val_acc: 0.108000
# (Epoch 1 / 20) train acc: 0.280000; val_acc: 0.095000
# (Epoch 2 / 20) train acc: 0.280000; val_acc: 0.091000
# (Epoch 3 / 20) train acc: 0.240000; val_acc: 0.094000
# (Epoch 4 / 20) train acc: 0.300000; val_acc: 0.089000
# (Epoch 5 / 20) train acc: 0.200000; val_acc: 0.123000
# (Iteration 11 / 40) loss: 2.166667
# (Epoch 3 / 20) train acc: 0.240000; val_acc: 0.094000
# (Epoch 4 / 20) train acc: 0.300000; val_acc: 0.089000
# (Epoch 5 / 20) train acc: 0.200000; val_acc: 0.123000
# (Iteration 11 / 40) loss: 2.166667
# (Epoch 6 / 20) train acc: 0.320000; val_acc: 0.118000
# (Epoch 7 / 20) train acc: 0.340000; val_acc: 0.128000
# (Epoch 8 / 20) train acc: 0.240000; val_acc: 0.086000
# (Epoch 9 / 20) train acc: 0.280000; val_acc: 0.121000
# (Epoch 6 / 20) train acc: 0.320000; val_acc: 0.118000
# (Epoch 7 / 20) train acc: 0.340000; val_acc: 0.128000
# (Epoch 8 / 20) train acc: 0.240000; val_acc: 0.086000
# (Epoch 9 / 20) train acc: 0.280000; val_acc: 0.121000
# (Epoch 10 / 20) train acc: 0.460000; val_acc: 0.153000
# (Iteration 21 / 40) loss: 1.764986
# (Epoch 11 / 20) train acc: 0.400000; val_acc: 0.161000
# (Epoch 12 / 20) train acc: 0.500000; val_acc: 0.180000
# (Epoch 10 / 20) train acc: 0.460000; val_acc: 0.153000
# (Iteration 21 / 40) loss: 1.764986
# (Epoch 11 / 20) train acc: 0.400000; val_acc: 0.161000
# (Epoch 12 / 20) train acc: 0.500000; val_acc: 0.180000
# (Epoch 13 / 20) train acc: 0.420000; val_acc: 0.164000
# (Epoch 14 / 20) train acc: 0.320000; val_acc: 0.126000
# (Epoch 15 / 20) train acc: 0.540000; val_acc: 0.176000
# (Iteration 31 / 40) loss: 1.643472
# (Epoch 16 / 20) train acc: 0.560000; val_acc: 0.145000
# (Epoch 13 / 20) train acc: 0.420000; val_acc: 0.164000
# (Epoch 14 / 20) train acc: 0.320000; val_acc: 0.126000
# (Epoch 15 / 20) train acc: 0.540000; val_acc: 0.176000
# (Iteration 31 / 40) loss: 1.643472
# (Epoch 16 / 20) train acc: 0.560000; val_acc: 0.145000
# (Epoch 17 / 20) train acc: 0.480000; val_acc: 0.191000
# (Epoch 18 / 20) train acc: 0.480000; val_acc: 0.172000
# (Epoch 19 / 20) train acc: 0.500000; val_acc: 0.147000
# (Epoch 20 / 20) train acc: 0.420000; val_acc: 0.155000
# weight_scale=2.00e-02, lr=5.00e-02, train_acc=0.4200, val_acc=0.1550
# (Epoch 17 / 20) train acc: 0.480000; val_acc: 0.191000
# (Epoch 18 / 20) train acc: 0.480000; val_acc: 0.172000
# (Epoch 19 / 20) train acc: 0.500000; val_acc: 0.147000
# (Epoch 20 / 20) train acc: 0.420000; val_acc: 0.155000
# weight_scale=2.00e-02, lr=5.00e-02, train_acc=0.4200, val_acc=0.1550
# (Iteration 1 / 40) loss: 2.303405
# (Epoch 0 / 20) train acc: 0.180000; val_acc: 0.112000
# (Epoch 1 / 20) train acc: 0.200000; val_acc: 0.126000
# (Epoch 2 / 20) train acc: 0.220000; val_acc: 0.120000
# (Iteration 1 / 40) loss: 2.303405
# (Epoch 0 / 20) train acc: 0.180000; val_acc: 0.112000
# (Epoch 1 / 20) train acc: 0.200000; val_acc: 0.126000
# (Epoch 2 / 20) train acc: 0.220000; val_acc: 0.120000
# (Epoch 3 / 20) train acc: 0.220000; val_acc: 0.123000
# (Epoch 4 / 20) train acc: 0.220000; val_acc: 0.120000
# (Epoch 5 / 20) train acc: 0.180000; val_acc: 0.127000
# (Iteration 11 / 40) loss: 1.981952
# (Epoch 3 / 20) train acc: 0.220000; val_acc: 0.123000
# (Epoch 4 / 20) train acc: 0.220000; val_acc: 0.120000
# (Epoch 5 / 20) train acc: 0.180000; val_acc: 0.127000
# (Iteration 11 / 40) loss: 1.981952
# (Epoch 6 / 20) train acc: 0.280000; val_acc: 0.143000
# (Epoch 7 / 20) train acc: 0.200000; val_acc: 0.088000
# (Epoch 8 / 20) train acc: 0.300000; val_acc: 0.112000
# (Epoch 6 / 20) train acc: 0.280000; val_acc: 0.143000
# (Epoch 7 / 20) train acc: 0.200000; val_acc: 0.088000
# (Epoch 8 / 20) train acc: 0.300000; val_acc: 0.112000
# (Epoch 9 / 20) train acc: 0.320000; val_acc: 0.135000
# (Epoch 10 / 20) train acc: 0.320000; val_acc: 0.115000
# (Iteration 21 / 40) loss: 1.810052
# (Epoch 11 / 20) train acc: 0.480000; val_acc: 0.129000
# (Epoch 9 / 20) train acc: 0.320000; val_acc: 0.135000
# (Epoch 10 / 20) train acc: 0.320000; val_acc: 0.115000
# (Iteration 21 / 40) loss: 1.810052
# (Epoch 11 / 20) train acc: 0.480000; val_acc: 0.129000
# (Epoch 12 / 20) train acc: 0.440000; val_acc: 0.137000
# (Epoch 13 / 20) train acc: 0.440000; val_acc: 0.151000
# (Epoch 14 / 20) train acc: 0.460000; val_acc: 0.158000
# (Epoch 15 / 20) train acc: 0.620000; val_acc: 0.161000
# (Iteration 31 / 40) loss: 1.572938
# (Epoch 12 / 20) train acc: 0.440000; val_acc: 0.137000
# (Epoch 13 / 20) train acc: 0.440000; val_acc: 0.151000
# (Epoch 14 / 20) train acc: 0.460000; val_acc: 0.158000
# (Epoch 15 / 20) train acc: 0.620000; val_acc: 0.161000
# (Iteration 31 / 40) loss: 1.572938
# (Epoch 16 / 20) train acc: 0.520000; val_acc: 0.174000
# (Epoch 17 / 20) train acc: 0.460000; val_acc: 0.178000
# (Epoch 18 / 20) train acc: 0.660000; val_acc: 0.167000
# (Epoch 16 / 20) train acc: 0.520000; val_acc: 0.174000
# (Epoch 17 / 20) train acc: 0.460000; val_acc: 0.178000
# (Epoch 18 / 20) train acc: 0.660000; val_acc: 0.167000
# (Epoch 19 / 20) train acc: 0.560000; val_acc: 0.163000
# (Epoch 20 / 20) train acc: 0.600000; val_acc: 0.171000
# weight_scale=2.00e-02, lr=7.00e-02, train_acc=0.6000, val_acc=0.1710
# (Iteration 1 / 40) loss: 2.319021
# (Epoch 0 / 20) train acc: 0.180000; val_acc: 0.130000
# (Epoch 19 / 20) train acc: 0.560000; val_acc: 0.163000
# (Epoch 20 / 20) train acc: 0.600000; val_acc: 0.171000
# weight_scale=2.00e-02, lr=7.00e-02, train_acc=0.6000, val_acc=0.1710
# (Iteration 1 / 40) loss: 2.319021
# (Epoch 0 / 20) train acc: 0.180000; val_acc: 0.130000
# (Epoch 1 / 20) train acc: 0.260000; val_acc: 0.140000
# (Epoch 2 / 20) train acc: 0.260000; val_acc: 0.133000
# (Epoch 1 / 20) train acc: 0.260000; val_acc: 0.140000
# (Epoch 2 / 20) train acc: 0.260000; val_acc: 0.133000
# (Epoch 3 / 20) train acc: 0.200000; val_acc: 0.115000
# (Epoch 3 / 20) train acc: 0.200000; val_acc: 0.115000
# (Epoch 4 / 20) train acc: 0.320000; val_acc: 0.119000
# (Epoch 5 / 20) train acc: 0.300000; val_acc: 0.150000
# (Iteration 11 / 40) loss: 1.917254
# (Epoch 6 / 20) train acc: 0.200000; val_acc: 0.104000
# (Epoch 4 / 20) train acc: 0.320000; val_acc: 0.119000
# (Epoch 5 / 20) train acc: 0.300000; val_acc: 0.150000
# (Iteration 11 / 40) loss: 1.917254
# (Epoch 6 / 20) train acc: 0.200000; val_acc: 0.104000
# (Epoch 7 / 20) train acc: 0.180000; val_acc: 0.082000
# (Epoch 8 / 20) train acc: 0.160000; val_acc: 0.079000
# (Epoch 9 / 20) train acc: 0.200000; val_acc: 0.112000
# (Epoch 10 / 20) train acc: 0.160000; val_acc: 0.071000
# (Iteration 21 / 40) loss: 2.242997
# (Epoch 7 / 20) train acc: 0.180000; val_acc: 0.082000
# (Epoch 8 / 20) train acc: 0.160000; val_acc: 0.079000
# (Epoch 9 / 20) train acc: 0.200000; val_acc: 0.112000
# (Epoch 10 / 20) train acc: 0.160000; val_acc: 0.071000
# (Iteration 21 / 40) loss: 2.242997
# (Epoch 11 / 20) train acc: 0.160000; val_acc: 0.078000
# (Epoch 12 / 20) train acc: 0.220000; val_acc: 0.114000
# (Epoch 13 / 20) train acc: 0.220000; val_acc: 0.139000
# (Epoch 11 / 20) train acc: 0.160000; val_acc: 0.078000
# (Epoch 12 / 20) train acc: 0.220000; val_acc: 0.114000
# (Epoch 13 / 20) train acc: 0.220000; val_acc: 0.139000
# (Epoch 14 / 20) train acc: 0.380000; val_acc: 0.142000
# (Epoch 15 / 20) train acc: 0.240000; val_acc: 0.118000
# (Iteration 31 / 40) loss: 2.180614
# (Epoch 16 / 20) train acc: 0.300000; val_acc: 0.094000
# (Epoch 17 / 20) train acc: 0.300000; val_acc: 0.124000
# (Epoch 14 / 20) train acc: 0.380000; val_acc: 0.142000
# (Epoch 15 / 20) train acc: 0.240000; val_acc: 0.118000
# (Iteration 31 / 40) loss: 2.180614
# (Epoch 16 / 20) train acc: 0.300000; val_acc: 0.094000
# (Epoch 17 / 20) train acc: 0.300000; val_acc: 0.124000
# (Epoch 18 / 20) train acc: 0.240000; val_acc: 0.129000
# (Epoch 19 / 20) train acc: 0.280000; val_acc: 0.159000
# (Epoch 20 / 20) train acc: 0.460000; val_acc: 0.181000
# weight_scale=2.00e-02, lr=1.00e-01, train_acc=0.4600, val_acc=0.1810
# (Iteration 1 / 40) loss: 2.335365
# (Epoch 0 / 20) train acc: 0.160000; val_acc: 0.087000
# (Epoch 1 / 20) train acc: 0.220000; val_acc: 0.090000
# (Epoch 2 / 20) train acc: 0.460000; val_acc: 0.133000
# (Epoch 18 / 20) train acc: 0.240000; val_acc: 0.129000
# (Epoch 19 / 20) train acc: 0.280000; val_acc: 0.159000
# (Epoch 20 / 20) train acc: 0.460000; val_acc: 0.181000
# weight_scale=2.00e-02, lr=1.00e-01, train_acc=0.4600, val_acc=0.1810
# (Iteration 1 / 40) loss: 2.335365
# (Epoch 0 / 20) train acc: 0.160000; val_acc: 0.087000
# (Epoch 1 / 20) train acc: 0.220000; val_acc: 0.090000
# (Epoch 2 / 20) train acc: 0.460000; val_acc: 0.133000
# (Epoch 3 / 20) train acc: 0.480000; val_acc: 0.148000
# (Epoch 4 / 20) train acc: 0.540000; val_acc: 0.128000
# (Epoch 5 / 20) train acc: 0.420000; val_acc: 0.146000
# (Iteration 11 / 40) loss: 1.459691
# (Epoch 6 / 20) train acc: 0.580000; val_acc: 0.155000
# (Epoch 3 / 20) train acc: 0.480000; val_acc: 0.148000
# (Epoch 4 / 20) train acc: 0.540000; val_acc: 0.128000
# (Epoch 5 / 20) train acc: 0.420000; val_acc: 0.146000
# (Iteration 11 / 40) loss: 1.459691
# (Epoch 6 / 20) train acc: 0.580000; val_acc: 0.155000
# (Epoch 7 / 20) train acc: 0.500000; val_acc: 0.137000
# (Epoch 8 / 20) train acc: 0.680000; val_acc: 0.143000
# (Epoch 9 / 20) train acc: 0.720000; val_acc: 0.144000
# (Epoch 7 / 20) train acc: 0.500000; val_acc: 0.137000
# (Epoch 8 / 20) train acc: 0.680000; val_acc: 0.143000
# (Epoch 9 / 20) train acc: 0.720000; val_acc: 0.144000
# (Epoch 10 / 20) train acc: 0.800000; val_acc: 0.171000
# (Iteration 21 / 40) loss: 0.924645
# (Epoch 11 / 20) train acc: 0.840000; val_acc: 0.146000
# (Epoch 12 / 20) train acc: 0.800000; val_acc: 0.124000
# (Epoch 10 / 20) train acc: 0.800000; val_acc: 0.171000
# (Iteration 21 / 40) loss: 0.924645
# (Epoch 11 / 20) train acc: 0.840000; val_acc: 0.146000
# (Epoch 12 / 20) train acc: 0.800000; val_acc: 0.124000
# (Epoch 13 / 20) train acc: 0.920000; val_acc: 0.175000
# (Epoch 14 / 20) train acc: 0.980000; val_acc: 0.175000
# (Epoch 15 / 20) train acc: 0.940000; val_acc: 0.160000
# (Iteration 31 / 40) loss: 0.235552
# (Epoch 13 / 20) train acc: 0.920000; val_acc: 0.175000
# (Epoch 14 / 20) train acc: 0.980000; val_acc: 0.175000
# (Epoch 15 / 20) train acc: 0.940000; val_acc: 0.160000
# (Iteration 31 / 40) loss: 0.235552
# (Epoch 16 / 20) train acc: 0.740000; val_acc: 0.159000
# (Epoch 17 / 20) train acc: 0.900000; val_acc: 0.189000
# (Epoch 18 / 20) train acc: 0.940000; val_acc: 0.160000
# (Epoch 19 / 20) train acc: 1.000000; val_acc: 0.177000
# (Epoch 20 / 20) train acc: 1.000000; val_acc: 0.181000
# weight_scale=3.00e-02, lr=3.00e-02, train_acc=1.0000, val_acc=0.1810
# 最佳五层网络配置: {'weight_scale': 0.03, 'learning_rate': 0.03}
# (Epoch 16 / 20) train acc: 0.740000; val_acc: 0.159000
# (Epoch 17 / 20) train acc: 0.900000; val_acc: 0.189000
# (Epoch 18 / 20) train acc: 0.940000; val_acc: 0.160000
# (Epoch 19 / 20) train acc: 1.000000; val_acc: 0.177000
# (Epoch 20 / 20) train acc: 1.000000; val_acc: 0.181000
# weight_scale=3.00e-02, lr=3.00e-02, train_acc=1.0000, val_acc=0.1810
# 最佳五层网络配置: {'weight_scale': 0.03, 'learning_rate': 0.03}

# %% [markdown]
# ## Inline Question 1:
# Did you notice anything about the comparative difficulty of training the three-layer network vs. training the five-layer network? In particular, based on your experience, which network seemed more sensitive to the initialization scale? Why do you think that is the case?
#
# ## Answer:
# 三层网络比较容易找到能收敛的学习率与权重尺度，五层网络则对初始化更敏感，稍微大或小都会导致梯度爆炸或消失。这是因为层数越深，前向的信号与反向的梯度都会在多次线性变换与非线性中被放大或缩小，初始权重的方差决定了这种链式效应的强度，深层结构对其放大更显著，因此需要更精细的初始化才能保持稳定训练。

# %% [markdown]
# # Update rules
# So far we have used vanilla stochastic gradient descent (SGD) as our update rule. More sophisticated update rules can make it easier to train deep networks. We will implement a few of the most commonly used update rules and compare them to vanilla SGD.

# %% [markdown]
# ## SGD+Momentum
# Stochastic gradient descent with momentum is a widely used update rule that tends to make deep networks converge faster than vanilla stochastic gradient descent. See the Momentum Update section at http://cs231n.github.io/neural-networks-3/#sgd for more information.
#
# Open the file `cs231n/optim.py` and read the documentation at the top of the file to make sure you understand the API. Implement the SGD+momentum update rule in the function `sgd_momentum` and run the following to check your implementation. You should see errors less than e-8.

# %%
from cs231n.optim import sgd_momentum

N, D = 4, 5
w = np.linspace(-0.4, 0.6, num=N*D).reshape(N, D)
dw = np.linspace(-0.6, 0.4, num=N*D).reshape(N, D)
v = np.linspace(0.6, 0.9, num=N*D).reshape(N, D)

config = {"learning_rate": 1e-3, "velocity": v}
next_w, _ = sgd_momentum(w, dw, config=config)

expected_next_w = np.asarray([
  [ 0.1406,      0.20738947,  0.27417895,  0.34096842,  0.40775789],
  [ 0.47454737,  0.54133684,  0.60812632,  0.67491579,  0.74170526],
  [ 0.80849474,  0.87528421,  0.94207368,  1.00886316,  1.07565263],
  [ 1.14244211,  1.20923158,  1.27602105,  1.34281053,  1.4096    ]])
expected_velocity = np.asarray([
  [ 0.5406,      0.55475789,  0.56891579, 0.58307368,  0.59723158],
  [ 0.61138947,  0.62554737,  0.63970526,  0.65386316,  0.66802105],
  [ 0.68217895,  0.69633684,  0.71049474,  0.72465263,  0.73881053],
  [ 0.75296842,  0.76712632,  0.78128421,  0.79544211,  0.8096    ]])

# Should see relative errors around e-8 or less
print("next_w error: ", rel_error(next_w, expected_next_w))
print("velocity error: ", rel_error(expected_velocity, config["velocity"]))
# Out:
# next_w error:  8.882347033505819e-09
# velocity error:  4.269287743278663e-09

# %% [markdown]
# Once you have done so, run the following to train a six-layer network with both SGD and SGD+momentum. You should see the SGD+momentum update rule converge faster.

# %%
num_train = 4000
small_data = {
  'X_train': data['X_train'][:num_train],
  'y_train': data['y_train'][:num_train],
  'X_val': data['X_val'],
  'y_val': data['y_val'],
}

solvers = {}

for update_rule in ['sgd', 'sgd_momentum']:
    print('Running with ', update_rule)
    model = FullyConnectedNet(
        [100, 100, 100, 100, 100],
        weight_scale=5e-2
    )

    solver = Solver(
        model,
        small_data,
        num_epochs=5,
        batch_size=100,
        update_rule=update_rule,
        optim_config={'learning_rate': 5e-3},
        verbose=True,
    )
    solvers[update_rule] = solver
    solver.train()

fig, axes = plt.subplots(3, 1, figsize=(15, 15))

axes[0].set_title('Training loss')
axes[0].set_xlabel('Iteration')
axes[1].set_title('Training accuracy')
axes[1].set_xlabel('Epoch')
axes[2].set_title('Validation accuracy')
axes[2].set_xlabel('Epoch')

for update_rule, solver in solvers.items():
    axes[0].plot(solver.loss_history, label=f"loss_{update_rule}")
    axes[1].plot(solver.train_acc_history, label=f"train_acc_{update_rule}")
    axes[2].plot(solver.val_acc_history, label=f"val_acc_{update_rule}")

for ax in axes:
    ax.legend(loc="best", ncol=4)
    ax.grid(linestyle='--', linewidth=0.5)

plt.show()
# Out:
# Running with  sgd
# (Iteration 1 / 200) loss: 2.882957
# (Epoch 0 / 5) train acc: 0.097000; val_acc: 0.083000
# (Iteration 11 / 200) loss: 2.280621
# (Iteration 21 / 200) loss: 2.252706
# (Iteration 31 / 200) loss: 2.117307
# (Epoch 1 / 5) train acc: 0.216000; val_acc: 0.179000
# (Iteration 41 / 200) loss: 2.096173
# (Iteration 51 / 200) loss: 2.149576
# (Iteration 61 / 200) loss: 2.136205
# (Iteration 71 / 200) loss: 2.178960
# (Epoch 2 / 5) train acc: 0.297000; val_acc: 0.235000
# (Iteration 81 / 200) loss: 1.973953
# (Epoch 1 / 5) train acc: 0.216000; val_acc: 0.179000
# (Iteration 41 / 200) loss: 2.096173
# (Iteration 51 / 200) loss: 2.149576
# (Iteration 61 / 200) loss: 2.136205
# (Iteration 71 / 200) loss: 2.178960
# (Epoch 2 / 5) train acc: 0.297000; val_acc: 0.235000
# (Iteration 81 / 200) loss: 1.973953
# (Iteration 91 / 200) loss: 2.042237
# (Iteration 101 / 200) loss: 1.929375
# (Iteration 111 / 200) loss: 1.893069
# (Iteration 91 / 200) loss: 2.042237
# (Iteration 101 / 200) loss: 1.929375
# (Iteration 111 / 200) loss: 1.893069
# (Epoch 3 / 5) train acc: 0.346000; val_acc: 0.265000
# (Iteration 121 / 200) loss: 1.965722
# (Iteration 131 / 200) loss: 1.866300
# (Iteration 141 / 200) loss: 1.944532
# (Iteration 151 / 200) loss: 1.771751
# (Epoch 4 / 5) train acc: 0.343000; val_acc: 0.273000
# (Iteration 161 / 200) loss: 1.853225
# (Epoch 3 / 5) train acc: 0.346000; val_acc: 0.265000
# (Iteration 121 / 200) loss: 1.965722
# (Iteration 131 / 200) loss: 1.866300
# (Iteration 141 / 200) loss: 1.944532
# (Iteration 151 / 200) loss: 1.771751
# (Epoch 4 / 5) train acc: 0.343000; val_acc: 0.273000
# (Iteration 161 / 200) loss: 1.853225
# (Iteration 171 / 200) loss: 1.917489
# (Iteration 181 / 200) loss: 1.796309
# (Iteration 191 / 200) loss: 1.953207
# (Epoch 5 / 5) train acc: 0.372000; val_acc: 0.288000
# Running with  sgd_momentum
# (Iteration 1 / 200) loss: 2.554652
# (Epoch 0 / 5) train acc: 0.094000; val_acc: 0.070000
# (Iteration 171 / 200) loss: 1.917489
# (Iteration 181 / 200) loss: 1.796309
# (Iteration 191 / 200) loss: 1.953207
# (Epoch 5 / 5) train acc: 0.372000; val_acc: 0.288000
# Running with  sgd_momentum
# (Iteration 1 / 200) loss: 2.554652
# (Epoch 0 / 5) train acc: 0.094000; val_acc: 0.070000
# (Iteration 11 / 200) loss: 2.230621
# (Iteration 21 / 200) loss: 2.069602
# (Iteration 31 / 200) loss: 1.961622
# (Epoch 1 / 5) train acc: 0.328000; val_acc: 0.275000
# (Iteration 41 / 200) loss: 1.826005
# (Iteration 51 / 200) loss: 1.679603
# (Iteration 11 / 200) loss: 2.230621
# (Iteration 21 / 200) loss: 2.069602
# (Iteration 31 / 200) loss: 1.961622
# (Epoch 1 / 5) train acc: 0.328000; val_acc: 0.275000
# (Iteration 41 / 200) loss: 1.826005
# (Iteration 51 / 200) loss: 1.679603
# (Iteration 61 / 200) loss: 1.817080
# (Iteration 71 / 200) loss: 1.833299
# (Epoch 2 / 5) train acc: 0.390000; val_acc: 0.298000
# (Iteration 81 / 200) loss: 1.697893
# (Iteration 91 / 200) loss: 1.777024
# (Iteration 61 / 200) loss: 1.817080
# (Iteration 71 / 200) loss: 1.833299
# (Epoch 2 / 5) train acc: 0.390000; val_acc: 0.298000
# (Iteration 81 / 200) loss: 1.697893
# (Iteration 91 / 200) loss: 1.777024
# (Iteration 101 / 200) loss: 1.589118
# (Iteration 111 / 200) loss: 1.327859
# (Epoch 3 / 5) train acc: 0.466000; val_acc: 0.329000
# (Iteration 121 / 200) loss: 1.615431
# (Iteration 131 / 200) loss: 1.599401
# (Iteration 141 / 200) loss: 1.381134
# (Iteration 101 / 200) loss: 1.589118
# (Iteration 111 / 200) loss: 1.327859
# (Epoch 3 / 5) train acc: 0.466000; val_acc: 0.329000
# (Iteration 121 / 200) loss: 1.615431
# (Iteration 131 / 200) loss: 1.599401
# (Iteration 141 / 200) loss: 1.381134
# (Iteration 151 / 200) loss: 1.404451
# (Epoch 4 / 5) train acc: 0.509000; val_acc: 0.342000
# (Iteration 161 / 200) loss: 1.301519
# (Iteration 171 / 200) loss: 1.401937
# (Iteration 181 / 200) loss: 1.241253
# (Iteration 191 / 200) loss: 1.412612
# (Iteration 151 / 200) loss: 1.404451
# (Epoch 4 / 5) train acc: 0.509000; val_acc: 0.342000
# (Iteration 161 / 200) loss: 1.301519
# (Iteration 171 / 200) loss: 1.401937
# (Iteration 181 / 200) loss: 1.241253
# (Iteration 191 / 200) loss: 1.412612
# (Epoch 5 / 5) train acc: 0.527000; val_acc: 0.354000
# (Epoch 5 / 5) train acc: 0.527000; val_acc: 0.354000

# %% [markdown]
# ## RMSProp and Adam
# RMSProp [1] and Adam [2] are update rules that set per-parameter learning rates by using a running average of the second moments of gradients.
#
# In the file `cs231n/optim.py`, implement the RMSProp update rule in the `rmsprop` function and implement the Adam update rule in the `adam` function, and check your implementations using the tests below.
#
# **NOTE:** Please implement the _complete_ Adam update rule (with the bias correction mechanism), not the first simplified version mentioned in the course notes.
#
# [1] Tijmen Tieleman and Geoffrey Hinton. "Lecture 6.5-rmsprop: Divide the gradient by a running average of its recent magnitude." COURSERA: Neural Networks for Machine Learning 4 (2012).
#
# [2] Diederik Kingma and Jimmy Ba, "Adam: A Method for Stochastic Optimization", ICLR 2015.

# %%
# Test RMSProp implementation
from cs231n.optim import rmsprop

N, D = 4, 5
w = np.linspace(-0.4, 0.6, num=N*D).reshape(N, D)
dw = np.linspace(-0.6, 0.4, num=N*D).reshape(N, D)
cache = np.linspace(0.6, 0.9, num=N*D).reshape(N, D)

config = {'learning_rate': 1e-2, 'cache': cache}
next_w, _ = rmsprop(w, dw, config=config)

expected_next_w = np.asarray([
  [-0.39223849, -0.34037513, -0.28849239, -0.23659121, -0.18467247],
  [-0.132737,   -0.08078555, -0.02881884,  0.02316247,  0.07515774],
  [ 0.12716641,  0.17918792,  0.23122175,  0.28326742,  0.33532447],
  [ 0.38739248,  0.43947102,  0.49155973,  0.54365823,  0.59576619]])
expected_cache = np.asarray([
  [ 0.5976,      0.6126277,   0.6277108,   0.64284931,  0.65804321],
  [ 0.67329252,  0.68859723,  0.70395734,  0.71937285,  0.73484377],
  [ 0.75037008,  0.7659518,   0.78158892,  0.79728144,  0.81302936],
  [ 0.82883269,  0.84469141,  0.86060554,  0.87657507,  0.8926    ]])

# You should see relative errors around e-7 or less
print('next_w error: ', rel_error(expected_next_w, next_w))
print('cache error: ', rel_error(expected_cache, config['cache']))
# Out:
# next_w error:  9.524687511038133e-08
# cache error:  2.6477955807156126e-09

# %%
# Test Adam implementation
from cs231n.optim import adam

N, D = 4, 5
w = np.linspace(-0.4, 0.6, num=N*D).reshape(N, D)
dw = np.linspace(-0.6, 0.4, num=N*D).reshape(N, D)
m = np.linspace(0.6, 0.9, num=N*D).reshape(N, D)
v = np.linspace(0.7, 0.5, num=N*D).reshape(N, D)

config = {'learning_rate': 1e-2, 'm': m, 'v': v, 't': 5}
next_w, _ = adam(w, dw, config=config)

expected_next_w = np.asarray([
  [-0.40094747, -0.34836187, -0.29577703, -0.24319299, -0.19060977],
  [-0.1380274,  -0.08544591, -0.03286534,  0.01971428,  0.0722929],
  [ 0.1248705,   0.17744702,  0.23002243,  0.28259667,  0.33516969],
  [ 0.38774145,  0.44031188,  0.49288093,  0.54544852,  0.59801459]])
expected_v = np.asarray([
  [ 0.69966,     0.68908382,  0.67851319,  0.66794809,  0.65738853,],
  [ 0.64683452,  0.63628604,  0.6257431,   0.61520571,  0.60467385,],
  [ 0.59414753,  0.58362676,  0.57311152,  0.56260183,  0.55209767,],
  [ 0.54159906,  0.53110598,  0.52061845,  0.51013645,  0.49966,   ]])
expected_m = np.asarray([
  [ 0.48,        0.49947368,  0.51894737,  0.53842105,  0.55789474],
  [ 0.57736842,  0.59684211,  0.61631579,  0.63578947,  0.65526316],
  [ 0.67473684,  0.69421053,  0.71368421,  0.73315789,  0.75263158],
  [ 0.77210526,  0.79157895,  0.81105263,  0.83052632,  0.85      ]])

# You should see relative errors around e-7 or less
print('next_w error: ', rel_error(expected_next_w, next_w))
print('v error: ', rel_error(expected_v, config['v']))
print('m error: ', rel_error(expected_m, config['m']))
# Out:
# next_w error:  1.1395691798535431e-07
# v error:  4.208314038113071e-09
# m error:  4.214963193114416e-09

# %% [markdown]
# Once you have debugged your RMSProp and Adam implementations, run the following to train a pair of deep networks using these new update rules:

# %%
learning_rates = {'rmsprop': 1e-4, 'adam': 1e-3}
for update_rule in ['adam', 'rmsprop']:
    print('Running with ', update_rule)
    model = FullyConnectedNet(
        [100, 100, 100, 100, 100],
        weight_scale=5e-2
    )
    solver = Solver(
        model,
        small_data,
        num_epochs=5,
        batch_size=100,
        update_rule=update_rule,
        optim_config={'learning_rate': learning_rates[update_rule]},
        verbose=True
    )
    solvers[update_rule] = solver
    solver.train()
    print()

fig, axes = plt.subplots(3, 1, figsize=(15, 15))

axes[0].set_title('Training loss')
axes[0].set_xlabel('Iteration')
axes[1].set_title('Training accuracy')
axes[1].set_xlabel('Epoch')
axes[2].set_title('Validation accuracy')
axes[2].set_xlabel('Epoch')

for update_rule, solver in solvers.items():
    axes[0].plot(solver.loss_history, label=f"{update_rule}")
    axes[1].plot(solver.train_acc_history, label=f"{update_rule}")
    axes[2].plot(solver.val_acc_history, label=f"{update_rule}")

for ax in axes:
    ax.legend(loc='best', ncol=4)
    ax.grid(linestyle='--', linewidth=0.5)

plt.show()
# Out:
# Running with  adam
# (Iteration 1 / 200) loss: 2.991785
# (Epoch 0 / 5) train acc: 0.127000; val_acc: 0.144000
# (Iteration 11 / 200) loss: 1.983391
# (Iteration 21 / 200) loss: 1.804156
# (Iteration 31 / 200) loss: 1.949393
# (Epoch 1 / 5) train acc: 0.367000; val_acc: 0.330000
# (Iteration 41 / 200) loss: 1.764917
# (Iteration 51 / 200) loss: 1.885474
# (Iteration 61 / 200) loss: 1.738757
# (Iteration 21 / 200) loss: 1.804156
# (Iteration 31 / 200) loss: 1.949393
# (Epoch 1 / 5) train acc: 0.367000; val_acc: 0.330000
# (Iteration 41 / 200) loss: 1.764917
# (Iteration 51 / 200) loss: 1.885474
# (Iteration 61 / 200) loss: 1.738757
# (Iteration 71 / 200) loss: 1.694796
# (Epoch 2 / 5) train acc: 0.447000; val_acc: 0.368000
# (Iteration 81 / 200) loss: 1.752641
# (Iteration 91 / 200) loss: 1.688883
# (Iteration 71 / 200) loss: 1.694796
# (Epoch 2 / 5) train acc: 0.447000; val_acc: 0.368000
# (Iteration 81 / 200) loss: 1.752641
# (Iteration 91 / 200) loss: 1.688883
# (Iteration 101 / 200) loss: 1.453844
# (Iteration 111 / 200) loss: 1.290089
# (Epoch 3 / 5) train acc: 0.505000; val_acc: 0.373000
# (Iteration 121 / 200) loss: 1.541716
# (Iteration 131 / 200) loss: 1.510193
# (Iteration 141 / 200) loss: 1.432664
# (Iteration 101 / 200) loss: 1.453844
# (Iteration 111 / 200) loss: 1.290089
# (Epoch 3 / 5) train acc: 0.505000; val_acc: 0.373000
# (Iteration 121 / 200) loss: 1.541716
# (Iteration 131 / 200) loss: 1.510193
# (Iteration 141 / 200) loss: 1.432664
# (Iteration 151 / 200) loss: 1.620555
# (Epoch 4 / 5) train acc: 0.549000; val_acc: 0.371000
# (Iteration 161 / 200) loss: 1.400906
# (Iteration 171 / 200) loss: 1.418737
# (Iteration 181 / 200) loss: 1.188082
# (Iteration 151 / 200) loss: 1.620555
# (Epoch 4 / 5) train acc: 0.549000; val_acc: 0.371000
# (Iteration 161 / 200) loss: 1.400906
# (Iteration 171 / 200) loss: 1.418737
# (Iteration 181 / 200) loss: 1.188082
# (Iteration 191 / 200) loss: 1.247170
# (Epoch 5 / 5) train acc: 0.602000; val_acc: 0.381000
#
# Running with  rmsprop
# (Iteration 1 / 200) loss: 2.820690
# (Epoch 0 / 5) train acc: 0.123000; val_acc: 0.128000
# (Iteration 11 / 200) loss: 2.094996
# (Iteration 21 / 200) loss: 1.960158
# (Iteration 31 / 200) loss: 1.966157
# (Iteration 191 / 200) loss: 1.247170
# (Epoch 5 / 5) train acc: 0.602000; val_acc: 0.381000
#
# Running with  rmsprop
# (Iteration 1 / 200) loss: 2.820690
# (Epoch 0 / 5) train acc: 0.123000; val_acc: 0.128000
# (Iteration 11 / 200) loss: 2.094996
# (Iteration 21 / 200) loss: 1.960158
# (Iteration 31 / 200) loss: 1.966157
# (Epoch 1 / 5) train acc: 0.357000; val_acc: 0.315000
# (Iteration 41 / 200) loss: 1.823676
# (Iteration 51 / 200) loss: 1.790478
# (Iteration 61 / 200) loss: 2.009011
# (Iteration 71 / 200) loss: 1.722353
# (Epoch 2 / 5) train acc: 0.425000; val_acc: 0.350000
# (Iteration 81 / 200) loss: 1.648287
# (Epoch 1 / 5) train acc: 0.357000; val_acc: 0.315000
# (Iteration 41 / 200) loss: 1.823676
# (Iteration 51 / 200) loss: 1.790478
# (Iteration 61 / 200) loss: 2.009011
# (Iteration 71 / 200) loss: 1.722353
# (Epoch 2 / 5) train acc: 0.425000; val_acc: 0.350000
# (Iteration 81 / 200) loss: 1.648287
# (Iteration 91 / 200) loss: 1.547375
# (Iteration 101 / 200) loss: 1.595498
# (Iteration 111 / 200) loss: 1.609111
# (Epoch 3 / 5) train acc: 0.457000; val_acc: 0.365000
# (Iteration 121 / 200) loss: 1.568150
# (Iteration 131 / 200) loss: 1.531994
# (Iteration 141 / 200) loss: 1.435974
# (Iteration 91 / 200) loss: 1.547375
# (Iteration 101 / 200) loss: 1.595498
# (Iteration 111 / 200) loss: 1.609111
# (Epoch 3 / 5) train acc: 0.457000; val_acc: 0.365000
# (Iteration 121 / 200) loss: 1.568150
# (Iteration 131 / 200) loss: 1.531994
# (Iteration 141 / 200) loss: 1.435974
# (Iteration 151 / 200) loss: 1.542655
# (Epoch 4 / 5) train acc: 0.513000; val_acc: 0.366000
# (Iteration 161 / 200) loss: 1.479819
# (Iteration 171 / 200) loss: 1.416847
# (Iteration 181 / 200) loss: 1.412308
# (Iteration 191 / 200) loss: 1.423452
# (Iteration 151 / 200) loss: 1.542655
# (Epoch 4 / 5) train acc: 0.513000; val_acc: 0.366000
# (Iteration 161 / 200) loss: 1.479819
# (Iteration 171 / 200) loss: 1.416847
# (Iteration 181 / 200) loss: 1.412308
# (Iteration 191 / 200) loss: 1.423452
# (Epoch 5 / 5) train acc: 0.513000; val_acc: 0.358000
#
# (Epoch 5 / 5) train acc: 0.513000; val_acc: 0.358000

# %% [markdown]
# ## Inline Question 2:
#
# AdaGrad, like Adam, is a per-parameter optimization method that uses the following update rule:
#
# ```
# cache += dw**2
# w += - learning_rate * dw / (np.sqrt(cache) + eps)
# ```
#
# John notices that when he was training a network with AdaGrad that the updates became very small, and that his network was learning slowly. Using your knowledge of the AdaGrad update rule, why do you think the updates would become very small? Would Adam have the same issue?
#
#
# ## Answer:
# AdaGrad把历史梯度平方累加在cache中，随着训练进行cache单调增大，分母越来越大，步长自然变得很小，所以后期几乎更新不了。Adam会对一阶与二阶矩做指数滑动平均并加入偏差校正，旧梯度的影响会衰减，因此不会像AdaGrad那样永久地把步长压到接近零。

# %% [markdown]
# # Train a Good Model!
# Train the best fully connected model that you can on CIFAR-10, storing your best model in the `best_model` variable. We require you to get at least 50% accuracy on the validation set using a fully connected network.
#
# If you are careful it should be possible to get accuracies above 55%, but we don't require it for this part and won't assign extra credit for doing so. Later in the next assignment, we will ask you to train the best convolutional network that you can on CIFAR-10, and we would prefer that you spend your effort working on convolutional networks rather than fully connected networks.
#
# **Note:** In the next assignment, you will learn techniques like BatchNormalization and Dropout which can help you train powerful models.

# %%
best_model = None

################################################################################
# TODO: Train the best FullyConnectedNet that you can on CIFAR-10. You might   #
# find batch/layer normalization and dropout useful. Store your best model in  #
# the best_model variable.                                                     #
################################################################################
# *****START OF YOUR CODE (DO NOT DELETE/MODIFY THIS LINE)*****
search_configs = [
    {
        "hidden_dims": [512, 256, 256],
        "dropout_keep_ratio": 0.9,
        "reg": 1e-4,
        "weight_scale": 1.5e-2,
        "learning_rate": 1.5e-3,
        "lr_decay": 0.95,
        "num_epochs": 20,
        "batch_size": 200,
        "update_rule": "adam",
    },
    {
        "hidden_dims": [512, 512, 256],
        "dropout_keep_ratio": 0.85,
        "reg": 2e-4,
        "weight_scale": 1.2e-2,
        "learning_rate": 1e-3,
        "lr_decay": 0.94,
        "num_epochs": 22,
        "batch_size": 200,
        "update_rule": "adam",
    },
    {
        "hidden_dims": [512, 256],
        "dropout_keep_ratio": 1.0,
        "reg": 8e-5,
        "weight_scale": 1e-2,
        "learning_rate": 1.8e-3,
        "lr_decay": 0.9,
        "num_epochs": 25,
        "batch_size": 256,
        "update_rule": "adam",
    },
]

best_val_acc = -1
best_solver = None
best_config = None

for cfg in search_configs:
    print("尝试配置:", cfg)
    model = FullyConnectedNet(
        hidden_dims=cfg["hidden_dims"],
        input_dim=32 * 32 * 3,
        num_classes=10,
        dropout_keep_ratio=cfg["dropout_keep_ratio"],
        normalization=None,
        reg=cfg["reg"],
        weight_scale=cfg["weight_scale"],
        dtype=np.float32,
    )
    solver = Solver(
        model,
        data,
        num_epochs=cfg["num_epochs"],
        batch_size=cfg["batch_size"],
        update_rule=cfg["update_rule"],
        optim_config={"learning_rate": cfg["learning_rate"]},
        lr_decay=cfg["lr_decay"],
        verbose=False,
    )
    solver.train()
    val_acc = solver.best_val_acc
    print(f"验证集最佳准确率: {val_acc:.4f}")
    if val_acc > best_val_acc:
        best_val_acc = val_acc
        best_model = model
        best_solver = solver
        best_config = cfg

print("最优配置:", best_config)
print("最优验证准确率: %.4f" % best_val_acc)
# *****END OF YOUR CODE (DO NOT DELETE/MODIFY THIS LINE)*****
################################################################################
#                              END OF YOUR CODE                                #
################################################################################
# Out:
# 尝试配置: {'hidden_dims': [512, 256, 256], 'dropout_keep_ratio': 0.9, 'reg': 0.0001, 'weight_scale': 0.015, 'learning_rate': 0.0015, 'lr_decay': 0.95, 'num_epochs': 20, 'batch_size': 200, 'update_rule': 'adam'}
# 验证集最佳准确率: 0.5360
# 尝试配置: {'hidden_dims': [512, 512, 256], 'dropout_keep_ratio': 0.85, 'reg': 0.0002, 'weight_scale': 0.012, 'learning_rate': 0.001, 'lr_decay': 0.94, 'num_epochs': 22, 'batch_size': 200, 'update_rule': 'adam'}
# 验证集最佳准确率: 0.5360
# 尝试配置: {'hidden_dims': [512, 512, 256], 'dropout_keep_ratio': 0.85, 'reg': 0.0002, 'weight_scale': 0.012, 'learning_rate': 0.001, 'lr_decay': 0.94, 'num_epochs': 22, 'batch_size': 200, 'update_rule': 'adam'}
# 验证集最佳准确率: 0.5520
# 尝试配置: {'hidden_dims': [512, 256], 'dropout_keep_ratio': 1.0, 'reg': 8e-05, 'weight_scale': 0.01, 'learning_rate': 0.0018, 'lr_decay': 0.9, 'num_epochs': 25, 'batch_size': 256, 'update_rule': 'adam'}
# 验证集最佳准确率: 0.5220
# 最优配置: {'hidden_dims': [512, 512, 256], 'dropout_keep_ratio': 0.85, 'reg': 0.0002, 'weight_scale': 0.012, 'learning_rate': 0.001, 'lr_decay': 0.94, 'num_epochs': 22, 'batch_size': 200, 'update_rule': 'adam'}
# 最优验证准确率: 0.5520

# %% [markdown]
# # Test Your Model!
# Run your best model on the validation and test sets. You should achieve at least 50% accuracy on the validation set and the test set.

# %%
y_test_pred = np.argmax(best_model.loss(data['X_test']), axis=1)
y_val_pred = np.argmax(best_model.loss(data['X_val']), axis=1)
print('Validation set accuracy: ', (y_val_pred == data['y_val']).mean())
print('Test set accuracy: ', (y_test_pred == data['y_test']).mean())
# Out:
# Validation set accuracy:  0.552
# Test set accuracy:  0.559
