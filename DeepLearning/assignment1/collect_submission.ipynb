# %%
from google.colab import drive

drive.mount('/content/drive')

# TODO: Enter the path in your Drive of the assignment.
# e.g. 'cs231n/assignments/assignment1/'
FOLDERNAME = 'cs231n/assignments/assignment1/'

assert FOLDERNAME is not None, "[!] Enter the foldername."
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Collect Submission - Zip + Generate PDF
#
# Run this notebook once you have completed all the other notebooks: `knn.ipynb`, `softmax.ipynb`, `two_layer_net.ipynb`, `features.ipynb`, and `FullyConnectedNets.ipynb`.
#
# It will:
#
# * Generate a zip file of your code (`.py` and `.ipynb`) called `a1_code_submission.zip`.
# * Convert all notebooks into a single PDF file called `a1_inline_submission.pdf`.
#
# If your submission for this step was successful, you should see the following display message:
#
# `### Done! Please submit a1_code_submission.zip and a1_inline_submission.pdf to Gradescope. ###`
#
# Make sure to download the zip and pdf file locally to your computer, then submit to Gradescope. Congrats on succesfully completing the assignment!

# %%
# %cd drive/My\ Drive
# %cd $FOLDERNAME
# !sudo apt-get install texlive-xetex texlive-fonts-recommended texlive-plain-generic texlive-latex-extra pandoc --fix-missing
# !pip install PyPDF2
# !bash collectSubmission.sh
# Out:
# Requirement already satisfied: PyPDF2 in /opt/homebrew/Caskroom/miniconda/base/envs/co-deeplearning/lib/python3.9/site-packages (3.0.1)
# Requirement already satisfied: typing_extensions>=3.10.0.0 in /opt/homebrew/Caskroom/miniconda/base/envs/co-deeplearning/lib/python3.9/site-packages (from PyPDF2) (4.14.1)
# ### Zipping file ###
# ### Creating PDFs ###
# Traceback (most recent call last):
#   File "/opt/homebrew/Caskroom/miniconda/base/envs/co-deeplearning/bin/jupyter-nbconvert", line 7, in <module>
#     sys.exit(main())
#   File "/opt/homebrew/Caskroom/miniconda/base/envs/co-deeplearning/lib/python3.9/site-packages/jupyter_core/application.py", line 284, in launch_instance
#     super().launch_instance(argv=argv, **kwargs)
#   File "/opt/homebrew/Caskroom/miniconda/base/envs/co-deeplearning/lib/python3.9/site-packages/traitlets/config/application.py", line 1075, in launch_instance
#     app.start()
#   File "/opt/homebrew/Caskroom/miniconda/base/envs/co-deeplearning/lib/python3.9/site-packages/nbconvert/nbconvertapp.py", line 420, in start
#     self.convert_notebooks()
#   File "/opt/homebrew/Caskroom/miniconda/base/envs/co-deeplearning/lib/python3.9/site-packages/nbconvert/nbconvertapp.py", line 597, in convert_notebooks
#     self.convert_single_notebook(notebook_filename)
#   File "/opt/homebrew/Caskroom/miniconda/base/envs/co-deeplearning/lib/python3.9/site-packages/nbconvert/nbconvertapp.py", line 563, in convert_single_notebook
#     output, resources = self.export_single_notebook(
#   File "/opt/homebrew/Caskroom/miniconda/base/envs/co-deeplearning/lib/python3.9/site-packages/nbconvert/nbconvertapp.py", line 487, in export_single_notebook
#     output, resources = self.exporter.from_filename(
#   File "/opt/homebrew/Caskroom/miniconda/base/envs/co-deeplearning/lib/python3.9/site-packages/nbconvert/exporters/templateexporter.py", line 390, in from_filename
#     return super().from_filename(filename, resources, **kw)  # type:ignore[return-value]
#   File "/opt/homebrew/Caskroom/miniconda/base/envs/co-deeplearning/lib/python3.9/site-packages/nbconvert/exporters/exporter.py", line 201, in from_filename
#     return self.from_file(f, resources=resources, **kw)
#   File "/opt/homebrew/Caskroom/miniconda/base/envs/co-deeplearning/lib/python3.9/site-packages/nbconvert/exporters/templateexporter.py", line 396, in from_file
#     return super().from_file(file_stream, resources, **kw)  # type:ignore[return-value]
#   File "/opt/homebrew/Caskroom/miniconda/base/envs/co-deeplearning/lib/python3.9/site-packages/nbconvert/exporters/exporter.py", line 220, in from_file
#     return self.from_notebook_node(
#   File "/opt/homebrew/Caskroom/miniconda/base/envs/co-deeplearning/lib/python3.9/site-packages/nbconvert/exporters/pdf.py", line 197, in from_notebook_node
#     self.run_latex(tex_file)
#   File "/opt/homebrew/Caskroom/miniconda/base/envs/co-deeplearning/lib/python3.9/site-packages/nbconvert/exporters/pdf.py", line 166, in run_latex
#     return self.run_command(
#   File "/opt/homebrew/Caskroom/miniconda/base/envs/co-deeplearning/lib/python3.9/site-packages/nbconvert/exporters/pdf.py", line 120, in run_command
#     raise OSError(msg)
# OSError: xelatex not found on PATH, if you have not installed xelatex you may need to do so. Find further instructions at https://nbconvert.readthedocs.io/en/latest/install.html#installing-tex.
# Created PDF knn.ipynb.
# Traceback (most recent call last):
#   File "/opt/homebrew/Caskroom/miniconda/base/envs/co-deeplearning/bin/jupyter-nbconvert", line 7, in <module>
#     sys.exit(main())
#   File "/opt/homebrew/Caskroom/miniconda/base/envs/co-deeplearning/lib/python3.9/site-packages/jupyter_core/application.py", line 284, in launch_instance
#     super().launch_instance(argv=argv, **kwargs)
#   File "/opt/homebrew/Caskroom/miniconda/base/envs/co-deeplearning/lib/python3.9/site-packages/traitlets/config/application.py", line 1075, in launch_instance
#     app.start()
#   File "/opt/homebrew/Caskroom/miniconda/base/envs/co-deeplearning/lib/python3.9/site-packages/nbconvert/nbconvertapp.py", line 420, in start
#     self.convert_notebooks()
#   File "/opt/homebrew/Caskroom/miniconda/base/envs/co-deeplearning/lib/python3.9/site-packages/nbconvert/nbconvertapp.py", line 597, in convert_notebooks
#     self.convert_single_notebook(notebook_filename)
#   File "/opt/homebrew/Caskroom/miniconda/base/envs/co-deeplearning/lib/python3.9/site-packages/nbconvert/nbconvertapp.py", line 563, in convert_single_notebook
#     output, resources = self.export_single_notebook(
#   File "/opt/homebrew/Caskroom/miniconda/base/envs/co-deeplearning/lib/python3.9/site-packages/nbconvert/nbconvertapp.py", line 487, in export_single_notebook
#     output, resources = self.exporter.from_filename(
#   File "/opt/homebrew/Caskroom/miniconda/base/envs/co-deeplearning/lib/python3.9/site-packages/nbconvert/exporters/templateexporter.py", line 390, in from_filename
#     return super().from_filename(filename, resources, **kw)  # type:ignore[return-value]
#   File "/opt/homebrew/Caskroom/miniconda/base/envs/co-deeplearning/lib/python3.9/site-packages/nbconvert/exporters/exporter.py", line 201, in from_filename
#     return self.from_file(f, resources=resources, **kw)
#   File "/opt/homebrew/Caskroom/miniconda/base/envs/co-deeplearning/lib/python3.9/site-packages/nbconvert/exporters/templateexporter.py", line 396, in from_file
#     return super().from_file(file_stream, resources, **kw)  # type:ignore[return-value]
#   File "/opt/homebrew/Caskroom/miniconda/base/envs/co-deeplearning/lib/python3.9/site-packages/nbconvert/exporters/exporter.py", line 220, in from_file
#     return self.from_notebook_node(
#   File "/opt/homebrew/Caskroom/miniconda/base/envs/co-deeplearning/lib/python3.9/site-packages/nbconvert/exporters/pdf.py", line 197, in from_notebook_node
#     self.run_latex(tex_file)
#   File "/opt/homebrew/Caskroom/miniconda/base/envs/co-deeplearning/lib/python3.9/site-packages/nbconvert/exporters/pdf.py", line 166, in run_latex
#     return self.run_command(
#   File "/opt/homebrew/Caskroom/miniconda/base/envs/co-deeplearning/lib/python3.9/site-packages/nbconvert/exporters/pdf.py", line 120, in run_command
#     raise OSError(msg)
# OSError: xelatex not found on PATH, if you have not installed xelatex you may need to do so. Find further instructions at https://nbconvert.readthedocs.io/en/latest/install.html#installing-tex.
# Created PDF softmax.ipynb.
# Traceback (most recent call last):
#   File "/opt/homebrew/Caskroom/miniconda/base/envs/co-deeplearning/bin/jupyter-nbconvert", line 7, in <module>
#     sys.exit(main())
#   File "/opt/homebrew/Caskroom/miniconda/base/envs/co-deeplearning/lib/python3.9/site-packages/jupyter_core/application.py", line 284, in launch_instance
#     super().launch_instance(argv=argv, **kwargs)
#   File "/opt/homebrew/Caskroom/miniconda/base/envs/co-deeplearning/lib/python3.9/site-packages/traitlets/config/application.py", line 1075, in launch_instance
#     app.start()
#   File "/opt/homebrew/Caskroom/miniconda/base/envs/co-deeplearning/lib/python3.9/site-packages/nbconvert/nbconvertapp.py", line 420, in start
#     self.convert_notebooks()
#   File "/opt/homebrew/Caskroom/miniconda/base/envs/co-deeplearning/lib/python3.9/site-packages/nbconvert/nbconvertapp.py", line 597, in convert_notebooks
#     self.convert_single_notebook(notebook_filename)
#   File "/opt/homebrew/Caskroom/miniconda/base/envs/co-deeplearning/lib/python3.9/site-packages/nbconvert/nbconvertapp.py", line 563, in convert_single_notebook
#     output, resources = self.export_single_notebook(
#   File "/opt/homebrew/Caskroom/miniconda/base/envs/co-deeplearning/lib/python3.9/site-packages/nbconvert/nbconvertapp.py", line 487, in export_single_notebook
#     output, resources = self.exporter.from_filename(
#   File "/opt/homebrew/Caskroom/miniconda/base/envs/co-deeplearning/lib/python3.9/site-packages/nbconvert/exporters/templateexporter.py", line 390, in from_filename
#     return super().from_filename(filename, resources, **kw)  # type:ignore[return-value]
#   File "/opt/homebrew/Caskroom/miniconda/base/envs/co-deeplearning/lib/python3.9/site-packages/nbconvert/exporters/exporter.py", line 201, in from_filename
#     return self.from_file(f, resources=resources, **kw)
#   File "/opt/homebrew/Caskroom/miniconda/base/envs/co-deeplearning/lib/python3.9/site-packages/nbconvert/exporters/templateexporter.py", line 396, in from_file
#     return super().from_file(file_stream, resources, **kw)  # type:ignore[return-value]
#   File "/opt/homebrew/Caskroom/miniconda/base/envs/co-deeplearning/lib/python3.9/site-packages/nbconvert/exporters/exporter.py", line 220, in from_file
#     return self.from_notebook_node(
#   File "/opt/homebrew/Caskroom/miniconda/base/envs/co-deeplearning/lib/python3.9/site-packages/nbconvert/exporters/pdf.py", line 197, in from_notebook_node
#     self.run_latex(tex_file)
#   File "/opt/homebrew/Caskroom/miniconda/base/envs/co-deeplearning/lib/python3.9/site-packages/nbconvert/exporters/pdf.py", line 166, in run_latex
#     return self.run_command(
#   File "/opt/homebrew/Caskroom/miniconda/base/envs/co-deeplearning/lib/python3.9/site-packages/nbconvert/exporters/pdf.py", line 120, in run_command
#     raise OSError(msg)
# OSError: xelatex not found on PATH, if you have not installed xelatex you may need to do so. Find further instructions at https://nbconvert.readthedocs.io/en/latest/install.html#installing-tex.
# Created PDF two_layer_net.ipynb.
# Traceback (most recent call last):
#   File "/opt/homebrew/Caskroom/miniconda/base/envs/co-deeplearning/bin/jupyter-nbconvert", line 7, in <module>
#     sys.exit(main())
#   File "/opt/homebrew/Caskroom/miniconda/base/envs/co-deeplearning/lib/python3.9/site-packages/jupyter_core/application.py", line 284, in launch_instance
#     super().launch_instance(argv=argv, **kwargs)
#   File "/opt/homebrew/Caskroom/miniconda/base/envs/co-deeplearning/lib/python3.9/site-packages/traitlets/config/application.py", line 1075, in launch_instance
#     app.start()
#   File "/opt/homebrew/Caskroom/miniconda/base/envs/co-deeplearning/lib/python3.9/site-packages/nbconvert/nbconvertapp.py", line 420, in start
#     self.convert_notebooks()
#   File "/opt/homebrew/Caskroom/miniconda/base/envs/co-deeplearning/lib/python3.9/site-packages/nbconvert/nbconvertapp.py", line 597, in convert_notebooks
#     self.convert_single_notebook(notebook_filename)
#   File "/opt/homebrew/Caskroom/miniconda/base/envs/co-deeplearning/lib/python3.9/site-packages/nbconvert/nbconvertapp.py", line 563, in convert_single_notebook
#     output, resources = self.export_single_notebook(
#   File "/opt/homebrew/Caskroom/miniconda/base/envs/co-deeplearning/lib/python3.9/site-packages/nbconvert/nbconvertapp.py", line 487, in export_single_notebook
#     output, resources = self.exporter.from_filename(
#   File "/opt/homebrew/Caskroom/miniconda/base/envs/co-deeplearning/lib/python3.9/site-packages/nbconvert/exporters/templateexporter.py", line 390, in from_filename
#     return super().from_filename(filename, resources, **kw)  # type:ignore[return-value]
#   File "/opt/homebrew/Caskroom/miniconda/base/envs/co-deeplearning/lib/python3.9/site-packages/nbconvert/exporters/exporter.py", line 201, in from_filename
#     return self.from_file(f, resources=resources, **kw)
#   File "/opt/homebrew/Caskroom/miniconda/base/envs/co-deeplearning/lib/python3.9/site-packages/nbconvert/exporters/templateexporter.py", line 396, in from_file
#     return super().from_file(file_stream, resources, **kw)  # type:ignore[return-value]
#   File "/opt/homebrew/Caskroom/miniconda/base/envs/co-deeplearning/lib/python3.9/site-packages/nbconvert/exporters/exporter.py", line 220, in from_file
#     return self.from_notebook_node(
#   File "/opt/homebrew/Caskroom/miniconda/base/envs/co-deeplearning/lib/python3.9/site-packages/nbconvert/exporters/pdf.py", line 197, in from_notebook_node
#     self.run_latex(tex_file)
#   File "/opt/homebrew/Caskroom/miniconda/base/envs/co-deeplearning/lib/python3.9/site-packages/nbconvert/exporters/pdf.py", line 166, in run_latex
#     return self.run_command(
#   File "/opt/homebrew/Caskroom/miniconda/base/envs/co-deeplearning/lib/python3.9/site-packages/nbconvert/exporters/pdf.py", line 120, in run_command
#     raise OSError(msg)
# OSError: xelatex not found on PATH, if you have not installed xelatex you may need to do so. Find further instructions at https://nbconvert.readthedocs.io/en/latest/install.html#installing-tex.
# Created PDF features.ipynb.
# Traceback (most recent call last):
#   File "/opt/homebrew/Caskroom/miniconda/base/envs/co-deeplearning/bin/jupyter-nbconvert", line 7, in <module>
#     sys.exit(main())
#   File "/opt/homebrew/Caskroom/miniconda/base/envs/co-deeplearning/lib/python3.9/site-packages/jupyter_core/application.py", line 284, in launch_instance
#     super().launch_instance(argv=argv, **kwargs)
#   File "/opt/homebrew/Caskroom/miniconda/base/envs/co-deeplearning/lib/python3.9/site-packages/traitlets/config/application.py", line 1075, in launch_instance
#     app.start()
#   File "/opt/homebrew/Caskroom/miniconda/base/envs/co-deeplearning/lib/python3.9/site-packages/nbconvert/nbconvertapp.py", line 420, in start
#     self.convert_notebooks()
#   File "/opt/homebrew/Caskroom/miniconda/base/envs/co-deeplearning/lib/python3.9/site-packages/nbconvert/nbconvertapp.py", line 597, in convert_notebooks
#     self.convert_single_notebook(notebook_filename)
#   File "/opt/homebrew/Caskroom/miniconda/base/envs/co-deeplearning/lib/python3.9/site-packages/nbconvert/nbconvertapp.py", line 563, in convert_single_notebook
#     output, resources = self.export_single_notebook(
#   File "/opt/homebrew/Caskroom/miniconda/base/envs/co-deeplearning/lib/python3.9/site-packages/nbconvert/nbconvertapp.py", line 487, in export_single_notebook
#     output, resources = self.exporter.from_filename(
#   File "/opt/homebrew/Caskroom/miniconda/base/envs/co-deeplearning/lib/python3.9/site-packages/nbconvert/exporters/templateexporter.py", line 390, in from_filename
#     return super().from_filename(filename, resources, **kw)  # type:ignore[return-value]
#   File "/opt/homebrew/Caskroom/miniconda/base/envs/co-deeplearning/lib/python3.9/site-packages/nbconvert/exporters/exporter.py", line 201, in from_filename
#     return self.from_file(f, resources=resources, **kw)
#   File "/opt/homebrew/Caskroom/miniconda/base/envs/co-deeplearning/lib/python3.9/site-packages/nbconvert/exporters/templateexporter.py", line 396, in from_file
#     return super().from_file(file_stream, resources, **kw)  # type:ignore[return-value]
#   File "/opt/homebrew/Caskroom/miniconda/base/envs/co-deeplearning/lib/python3.9/site-packages/nbconvert/exporters/exporter.py", line 220, in from_file
#     return self.from_notebook_node(
#   File "/opt/homebrew/Caskroom/miniconda/base/envs/co-deeplearning/lib/python3.9/site-packages/nbconvert/exporters/pdf.py", line 197, in from_notebook_node
#     self.run_latex(tex_file)
#   File "/opt/homebrew/Caskroom/miniconda/base/envs/co-deeplearning/lib/python3.9/site-packages/nbconvert/exporters/pdf.py", line 166, in run_latex
#     return self.run_command(
#   File "/opt/homebrew/Caskroom/miniconda/base/envs/co-deeplearning/lib/python3.9/site-packages/nbconvert/exporters/pdf.py", line 120, in run_command
#     raise OSError(msg)
# OSError: xelatex not found on PATH, if you have not installed xelatex you may need to do so. Find further instructions at https://nbconvert.readthedocs.io/en/latest/install.html#installing-tex.
# Created PDF FullyConnectedNets.ipynb.
# Traceback (most recent call last):
#   File "/Users/kiracoon/college/HDU-MTs/DeepLearning/assignment1/makepdf.py", line 46, in <module>
#     main(args.notebooks, args.pdf_filename)
#   File "/Users/kiracoon/college/HDU-MTs/DeepLearning/assignment1/makepdf.py", line 32, in main
#     merger.append(pdf)
#   File "/opt/homebrew/Caskroom/miniconda/base/envs/co-deeplearning/lib/python3.9/site-packages/PyPDF2/_utils.py", line 417, in wrapper
#     return func(*args, **kwargs)
#   File "/opt/homebrew/Caskroom/miniconda/base/envs/co-deeplearning/lib/python3.9/site-packages/PyPDF2/_merger.py", line 319, in append
#     self.merge(len(self.pages), fileobj, outline_item, pages, import_outline)
#   File "/opt/homebrew/Caskroom/miniconda/base/envs/co-deeplearning/lib/python3.9/site-packages/PyPDF2/_utils.py", line 417, in wrapper
#     return func(*args, **kwargs)
#   File "/opt/homebrew/Caskroom/miniconda/base/envs/co-deeplearning/lib/python3.9/site-packages/PyPDF2/_merger.py", line 194, in merge
#     stream, encryption_obj = self._create_stream(fileobj)
#   File "/opt/homebrew/Caskroom/miniconda/base/envs/co-deeplearning/lib/python3.9/site-packages/PyPDF2/_merger.py", line 263, in _create_stream
#     stream = FileIO(fileobj, "rb")
# FileNotFoundError: [Errno 2] No such file or directory: 'knn.pdf'
